# %%
# %%capture
# !pip install ipywidgets
# !pip install autogluon scikit-learn==1.5.2

# %%
# %%capture
# !apt-get install -y graphviz graphviz-dev && pip install pydot
# !pip install pygraphviz

# %%
import torch
import os
import pydot

import numpy as np
import pandas as pd
from time import time
from tqdm.auto import tqdm
from itertools import combinations

from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns
import bokeh
import shap

import warnings

warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

pd.options.mode.copy_on_write = True
pd.set_option('display.max_columns', 1000)
# plt.style.use("ggplot")
# sns.set_style("whitegrid")

## -- Ansi color codes --
COLOR = '\033[32m'
RESET = '\033[0m'

# %%
PATH       = "/kaggle/input/playground-series-s5e9/"
train      = pd.read_csv(PATH + "train.csv", index_col='id') #.drop('id', axis=1)
test       = pd.read_csv(PATH + "test.csv", index_col='id') #.drop('id', axis=1)

orig       = pd.read_csv("/kaggle/input/bpm-prediction-challenge/Train.csv")
orig['id'] = np.arange(len(orig))
orig       = orig.set_index('id')

submit     = pd.read_csv(PATH+"sample_submission.csv")

TARGET     = "BeatsPerMinute"
FEATURES   = test.columns.tolist()

LEN_TRAIN  = len(train)
LEN_TEST   = len(test)
LEN_ORIG   = len(orig)

# %%
def distplots_data(
                    train: pd.DataFrame,
                    test: pd.DataFrame,
                    orig: pd.DataFrame,
                    features: list[str]):

    df = pd.concat([train[features].assign(Source = 'Train'), 
                    test[features].assign(Source = 'Test'),
                    orig[features].assign(Source = 'Original'),], 
                    axis=0, ignore_index = True)

    fig, axs = plt.subplots(len(features), 2 ,figsize = (18, len(features) * 4), 
                            gridspec_kw = {
                                            'hspace': 0.2, 
                                            'wspace': 0.15, 
                                            'width_ratios': [0.7, 0.3]
                                    }
                    )
    PALETTE = ['g', 'r', 'orange']
    for i, col in enumerate(features):
        ax = axs[i, 0]
        sns.kdeplot(data = df[[col, 'Source']], x = col, hue = 'Source', 
                    palette = PALETTE, ax = ax, linewidth = 2
                   )
        ax.set(xlabel = '', ylabel = '')
        ax.set_title(f"\n{col}")
        ax.grid()

        ax = axs[i, 1]
        sns.boxplot(data = df, y=col, x=df['Source'], width = 0.5,
                    linewidth = 1, fliersize= 1, ax = ax, palette = PALETTE)
        ax.set_title(f"\n{col}")
        ax.set(xlabel = '', ylabel = '')
        ax.tick_params(axis='both', which='major')
        ax.set_xticklabels(['Train', 'Test', 'Original'])

    plt.tight_layout()
    plt.show()

# %%
distplots_data(train, test, orig, FEATURES)

# %%
# ## -- CREATE FEATURES -- ##
# def create_features(train, test):
#     train = train.copy()
#     test  = test.copy()
#     ## -- Feature 1: Use original as features
#     ORIG_FEATURES = []
#     print(f"Merging {len(FEATURES)} features... ", end="")
#     for c in FEATURES:
#         tmp = orig.groupby(c)[TARGET].mean()
#         n = f"orig_{c}"
#         print(f"{n}, ",end="")
#         tmp.name = n
#         train = train.merge(tmp, on=c, how='left')
#         test = test.merge(tmp, on=c, how='left')
#         ORIG_FEATURES.append(n)
        
#     print()

#     # Feature 2: Scaling
#     for df in [train, test]:
#         df["TrackDurationMin"] = df["TrackDurationMs"] / 60000
#         df["log_AcousticQuality"] = np.log1p(df["AcousticQuality"]).astype('float32')
#         df["sqrt_InstrumentalScore"] = np.sqrt(df["InstrumentalScore"]).astype('float32')
#         df["sqrt_VocalContent"] = np.sqrt(df["VocalContent"]).astype('float32')
#         df["sqrt_LivePerformance"] = np.sqrt(df["LivePerformanceLikelihood"]).astype('float32')

#         df["orig_TrackDurationMin"] = df["orig_TrackDurationMs"] / 60000
#         df["log_orig_AcousticQuality"] = np.log1p(df["orig_AcousticQuality"]).astype('float32')
#         df["sqrt_orig_InstrumentalScore"] = np.sqrt(df["orig_InstrumentalScore"]).astype('float32')
#         df["sqrt_orig_VocalContent"] = np.sqrt(df["orig_VocalContent"]).astype('float32')
#         df["sqrt_orig_LivePerformance"] = np.sqrt(df["orig_LivePerformanceLikelihood"]).astype('float32')

#     # ## -- Feature 3: Interactions
#     # X_INTERACTS = []
#     # D_INTERACTS = []
#     # for n in [2]:
#     #     for cols in tqdm(list(combinations(FEATURES, n)), desc="Creating interactions"):
#     #         ## -- Multiplication
#     #         n1 = '_x_'.join(sorted(cols))
#     #         train[n1] = (train[cols[0]] * train[cols[1]]).astype('float32')
#     #         test[n1] = (test[cols[0]] * test[cols[1]]).astype('float32')
#     #         Division
#     #         n2 = '_/_'.join(sorted(cols))
#     #         train[n2] = (train[cols[0]] / (train[cols[1]] + 1e-6)).astype('float32')
#     #         test[n2] = (test[cols[0]] / (test[cols[1]] + 1e-6)).astype('float32')
#     #         ## -- Inverse Division
#     #         n3 = '_\_'.join(sorted(cols))
#     #         train[n3] = (train[cols[1]] / (train[cols[0]] + 1e-6)).astype('float32')
#     #         test[n3] = (test[cols[1]] / (test[cols[0]] + 1e-6)).astype('float32')

#     #         ## -- X_INTERACTS.append(n1)
#     #         D_INTERACTS.append(n2)
#     #         D_INTERACTS.append(n3)
    
#     ## -- Feature 4: Quartile and Decile features
#     QT = 4
#     DE = 10
#     BINS = []
    
#     print(f"-> Creating {QT} & {DE} bins:")
#     for i, col in enumerate(FEATURES, 1):
#         print(f"Feat_{i}.. ", end="")

#         # Calculate quantiles based on the training set
#         QT_TRAIN = pd.qcut(train[col], q=QT, labels=False, duplicates='drop')
#         DE_TRAIN = pd.qcut(train[col], q=DE, labels=False, duplicates='drop')
        
#         QUAD = f"qt_{col.lower()}"
#         DECI  = f"de_{col.lower()}"
#         # Add binned features to train
#         train[QUAD] = QT_TRAIN
#         train[DECI] = DE_TRAIN

#         # Use the training quantiles to bin the test set
#         QT_BINS = train[col].quantile(np.linspace(0, 1, QT+1))
#         DE_BINS = train[col].quantile(np.linspace(0, 1, DE+1))
        
#         EXTRA = dict(labels=False, include_lowest=True, duplicates='drop')
        
#         test[QUAD] = pd.cut(test[col], bins=QT_BINS, **EXTRA)
#         test[DECI] = pd.cut(test[col], bins=DE_BINS, **EXTRA)

#         # Handle cases where pd.cut returns NaN
#         test[QUAD] = test[QUAD].fillna(-1)
#         test[DECI] = test[DECI].fillna(-1)

#         BINS.append(QUAD)
#         BINS.append(DECI)

#     # Feature 5: Pairwise combinations
#     TE_columns = []
#     for n in [2]:
#         for cols in tqdm(list(combinations(BINS, n)), desc="Creating combinations"):
#             name = '-'.join(sorted(cols))

#             # Create combos by concatenating string representations
#             train[name] = train[cols[0]].astype(str) + '_' + train[cols[1]].astype(str)
#             test[name] = test[cols[0]].astype(str) + '_' + test[cols[1]].astype(str)

#             # if n == 3: # --> Create 3-combo
#             #     train[name] += '_' + train[cols[2]].astype(str)
#             #     test[name] += '_' + test[cols[2]].astype(str)

#             # Fit the category encoder ONLY on the training data
#             train[name] = train[name].astype('category')
#             cat = train[name].cat
#             # Apply consistent encoding across datasets
#             train[name] = train[name].cat.codes
#             # Use the fitted category to transform the test and original sets
#             test[name] = pd.Categorical(test[name], categories=cat.categories).codes

#             TE_columns.append(name)

        
#     ##### ===================== ORIGINAL DATA OPERATIONS ======================== ###
#     orig_BINS = []
    
#     print(f"-> Creating {QT} & {DE} bins - ORIGNAL:")
#     for i, col in enumerate(ORIG_FEATURES, 1):
#         print(f"Feat_{i}.. ", end="")

#         # Calculate quantiles based on the training set
#         QT_TRAIN = pd.qcut(train[col], q=QT, labels=False, duplicates='drop')
#         DE_TRAIN = pd.qcut(train[col], q=DE, labels=False, duplicates='drop')
        
#         QUAD = f"qt_{col.lower()}"
#         DECI  = f"de_{col.lower()}"
#         # Add binned features to train
#         train[QUAD] = QT_TRAIN
#         train[DECI] = DE_TRAIN

#         # Use the training quantiles to bin the test set
#         QT_BINS = train[col].quantile(np.linspace(0, 1, QT+1))
#         DE_BINS = train[col].quantile(np.linspace(0, 1, DE+1))
        
#         EXTRA = dict(labels=False, include_lowest=True, duplicates='drop')
        
#         test[QUAD] = pd.cut(test[col], bins=QT_BINS, **EXTRA)
#         test[DECI] = pd.cut(test[col], bins=DE_BINS, **EXTRA)

#         # Handle cases where pd.cut returns NaN
#         test[QUAD] = test[QUAD].fillna(-1)
#         test[DECI] = test[DECI].fillna(-1)

#         orig_BINS.append(QUAD)
#         orig_BINS.append(DECI)
    
#     # Feature 5: Pairwise combinations
#     orig_TE_columns = []
#     for n in [2]:
#         for cols in tqdm(list(combinations(orig_BINS, n)), desc="Creating combinations -  ORIGINAL"):
#             name = '-'.join(sorted(cols))

#             # Create combos by concatenating string representations
#             train[name] = train[cols[0]].astype(str) + '_' + train[cols[1]].astype(str)
#             test[name] = test[cols[0]].astype(str) + '_' + test[cols[1]].astype(str)

#             # if n == 3: # --> Create 3-combo
#             #     train[name] += '_' + train[cols[2]].astype(str)
#             #     test[name] += '_' + test[cols[2]].astype(str)

#             # Fit the category encoder ONLY on the training data
#             train[name] = train[name].astype('category')
#             cat = train[name].cat
#             # Apply consistent encoding across datasets
#             train[name] = train[name].cat.codes
#             # Use the fitted category to transform the test and original sets
#             test[name] = pd.Categorical(test[name], categories=cat.categories).codes

#             orig_TE_columns.append(name)
            
#     print("Feature Engineering Complete!!!")
#     print(f"-> Binned features   : {len(BINS+orig_BINS)}")
#     print(f"-> Combinations (TE) : {len(TE_columns+orig_TE_columns)}")
#     print(f"---> TOTAL FEATURES  : {len(test.columns)}")

#     return train, test

# %%
## -- CREATE FEATURES -- ##
def create_features(train, test):
    # Feature 1: Scaling
    for df in [train, test]:
        df["TrackDurationMin"] = df["TrackDurationMs"] / 60000
        df["log_AcousticQuality"] = np.log1p(df["AcousticQuality"])
        df["sqrt_InstrumentalScore"] = np.sqrt(df["InstrumentalScore"])
        df["sqrt_VocalContent"] = np.sqrt(df["VocalContent"])
        df["sqrt_LivePerformance"] = np.sqrt(df["LivePerformanceLikelihood"])

    QT = 4
    DE = 10
    BINS = []
    
    print(f"Creating {QT} & {DE} bins:")
    for i, col in enumerate(FEATURES, 1):
        print(f"Col-{i}.. ", end="")

        # Calculate quantiles based on the training set
        QT_TRAIN = pd.qcut(train[col], q=QT, labels=False, duplicates='drop')
        DE_TRAIN = pd.qcut(train[col], q=DE, labels=False, duplicates='drop')
        
        QUAD = f"qt_{col.lower()}"
        DECI  = f"de_{col.lower()}"
        # Add binned features to train
        train[QUAD] = QT_TRAIN
        train[DECI] = DE_TRAIN

        # Use the training quantiles to bin the test set
        QT_BINS = train[col].quantile(np.linspace(0, 1, QT+1))
        DE_BINS = train[col].quantile(np.linspace(0, 1, DE+1))
        
        EXTRA = dict(labels=False, include_lowest=True, duplicates='drop')
        
        test[QUAD] = pd.cut(test[col], bins=QT_BINS, **EXTRA)
        test[DECI] = pd.cut(test[col], bins=DE_BINS, **EXTRA)

        # Handle cases where pd.cut returns NaN
        test[QUAD] = test[QUAD].fillna(-1)
        test[DECI] = test[DECI].fillna(-1)

        BINS.append(QUAD)
        BINS.append(DECI)

    # Feature 4: Pairwise combinations
    INTERACTIONS = []
    for n in [2]:
        for cols in tqdm(list(combinations(BINS, n)), desc="Creating interactions"):
            name = '-'.join(sorted(cols))

            # Create combos by concatenating string representations
            train[name] = train[cols[0]].astype(str) + '_' + train[cols[1]].astype(str)
            test[name] = test[cols[0]].astype(str) + '_' + test[cols[1]].astype(str)

            # if n == 3: # --> Create 3-combo
            #     train[name] += '_' + train[cols[2]].astype(str)
            #     test[name] += '_' + test[cols[2]].astype(str)

            # Fit the category encoder ONLY on the training data
            train[name] = train[name].astype('category')
            cat = train[name].cat
            # Apply consistent encoding across datasets
            train[name] = train[name].cat.codes
            # Use the fitted category to transform the test and original sets
            test[name] = pd.Categorical(test[name], categories=cat.categories).codes

            INTERACTIONS.append(name)

    print("Feature Engineering Complete!!!")
    print(f"-> Binned features   : {len(BINS)}")
    print(f"-> All Interactions  : {len(INTERACTIONS)}")
    print(f"---> TOTAL FEATURES  : {len(test.columns)}")

    return train, test
    
train, test = create_features(train, test)
# Out:
# Creating 4 & 10 bins:
# Col-1.. Col-2.. Col-3.. Col-4.. Col-5.. Col-6.. Col-7.. Col-8.. Col-9..
# Creating interactions:   0%|          | 0/153 [00:00<?, ?it/s]
# Feature Engineering Complete!!!
# -> Binned features   : 18
# -> All Interactions  : 153
# ---> TOTAL FEATURES  : 185

# %%
display(train.head())
train.shape
# Out:
#     RhythmScore  AudioLoudness  VocalContent  AcousticQuality  \
# id
# 0      0.603610      -7.636942      0.023500         0.000005
# 1      0.639451     -16.267598      0.071520         0.444929
# 2      0.514538     -15.953575      0.110715         0.173699
# 3      0.734463      -1.357000      0.052965         0.001651
# 4      0.532968     -13.056437      0.023500         0.068687
#
#     InstrumentalScore  LivePerformanceLikelihood  MoodScore  TrackDurationMs  \
# id
# 0            0.000001                   0.051385   0.409866      290715.6450
# 1            0.349414                   0.170522   0.651010      164519.5174
# 2            0.453814                   0.029576   0.423865      174495.5667
# 3            0.159717                   0.086366   0.278745      225567.4651
# 4            0.000001                   0.331345   0.477769      213960.6789
#
#       Energy  BeatsPerMinute  TrackDurationMin  log_AcousticQuality  \
# id
# 0   0.826267       147.53020          4.845261             0.000005
# 1   0.145400       136.15963          2.741992             0.368060
# 2   0.624667        55.31989          2.908259             0.160160
# 3   0.487467       147.91212          3.759458             0.001649
# 4   0.947333        89.58511          3.566011             0.066431
#
#     sqrt_InstrumentalScore  sqrt_VocalContent  sqrt_LivePerformance  \
# id
# 0                 0.001034           0.153297              0.226684
# 1                 0.591113           0.267431              0.412944
# 2                 0.673657           0.332738              0.171976
# 3                 0.399646           0.230140              0.293881
# 4                 0.001034           0.153297              0.575626
#
#     qt_rhythmscore  de_rhythmscore  qt_audioloudness  de_audioloudness  \
# id
# 0                1               4                 2                 5
# 1                2               5                 0                 0
# 2                0               2                 0                 0
# 3                2               7                 3                 8
# 4                1               2                 0                 1
#
#     qt_vocalcontent  de_vocalcontent  qt_acousticquality  de_acousticquality  \
# id
# 0                 0                0                   0                   0
# 1                 1                2                   3                   6
# 2                 2                4                   1                   3
# 3                 0                1                   0                   0
# 4                 0                0                   0                   1
#
#     qt_instrumentalscore  de_instrumentalscore  qt_liveperformancelikelihood  \
# id
# 0                      0                     0                             0
# 1                      2                     6                             2
# 2                      2                     6                             0
# 3                      1                     3                             1
# 4                      0                     0                             3
#
#     de_liveperformancelikelihood  qt_moodscore  de_moodscore  \
# id
# 0                              0             1             2
# 1                              4             2             6
# 2                              0             1             2
# 3                              1             0             1
# 4                              7             1             3
#
#     qt_trackdurationms  de_trackdurationms  qt_energy  de_energy  \
# id
# 0                    3                   7          3          8
# 1                    0                   1          0          1
# 2                    0                   1          2          6
# 3                    1                   3          1          4
# 4                    1                   2          3          9
#
#     de_rhythmscore-qt_rhythmscore  qt_audioloudness-qt_rhythmscore  \
# id
# 0                               5                                6
# 1                               6                                8
# 2                               2                                0
# 3                               8                               11
# 4                               3                                4
#
#     de_audioloudness-qt_rhythmscore  qt_rhythmscore-qt_vocalcontent  \
# id
# 0                                14                               3
# 1                                18                               7
# 2                                 0                               2
# 3                                26                               6
# 4                                10                               3
#
#     de_vocalcontent-qt_rhythmscore  qt_acousticquality-qt_rhythmscore  \
# id
# 0                                7                                  4
# 1                               16                                 11
# 2                                4                                  1
# 3                               15                                  8
# 4                                7                                  4
#
#     de_acousticquality-qt_rhythmscore  qt_instrumentalscore-qt_rhythmscore  \
# id
# 0                                   9                                    3
# 1                                  24                                    8
# 2                                   3                                    2
# 3                                  18                                    7
# 4                                  10                                    3
#
#     de_instrumentalscore-qt_rhythmscore  \
# id
# 0                                     7
# 1                                    20
# 2                                     6
# 3                                    17
# 4                                     7
#
#     qt_liveperformancelikelihood-qt_rhythmscore  \
# id
# 0                                             4
# 1                                            10
# 2                                             0
# 3                                             9
# 4                                             7
#
#     de_liveperformancelikelihood-qt_rhythmscore  qt_moodscore-qt_rhythmscore  \
# id
# 0                                             9                            5
# 1                                            22                           10
# 2                                             0                            1
# 3                                            19                            8
# 4                                            16                            5
#
#     de_moodscore-qt_rhythmscore  qt_rhythmscore-qt_trackdurationms  \
# id
# 0                            12                                  7
# 1                            26                                  8
# 2                             2                                  0
# 3                            21                                  9
# 4                            13                                  5
#
#     de_trackdurationms-qt_rhythmscore  qt_energy-qt_rhythmscore  \
# id
# 0                                  17                         7
# 1                                  21                         8
# 2                                   1                         2
# 3                                  23                         9
# 4                                  12                         7
#
#     de_energy-qt_rhythmscore  de_rhythmscore-qt_audioloudness  \
# id
# 0                         18                               18
# 1                         21                               20
# 2                          6                                8
# 3                         24                               31
# 4                         19                                8
#
#     de_audioloudness-de_rhythmscore  de_rhythmscore-qt_vocalcontent  \
# id
# 0                                41                              12
# 1                                45                              16
# 2                                18                               8
# 3                                71                              21
# 4                                19                               6
#
#     de_rhythmscore-de_vocalcontent  de_rhythmscore-qt_acousticquality  \
# id
# 0                               28                                 16
# 1                               37                                 23
# 2                               18                                  9
# 3                               50                                 28
# 4                               14                                  8
#
#     de_acousticquality-de_rhythmscore  de_rhythmscore-qt_instrumentalscore  \
# id
# 0                                  36                                   12
# 1                                  51                                   17
# 2                                  21                                    8
# 3                                  63                                   22
# 4                                  19                                    6
#
#     de_instrumentalscore-de_rhythmscore  \
# id
# 0                                    28
# 1                                    41
# 2                                    20
# 3                                    52
# 4                                    14
#
#     de_rhythmscore-qt_liveperformancelikelihood  \
# id
# 0                                            16
# 1                                            22
# 2                                             8
# 3                                            29
# 4                                            11
#
#     de_liveperformancelikelihood-de_rhythmscore  de_rhythmscore-qt_moodscore  \
# id
# 0                                            36                           17
# 1                                            49                           22
# 2                                            18                            9
# 3                                            64                           28
# 4                                            25                            9
#
#     de_moodscore-de_rhythmscore  de_rhythmscore-qt_trackdurationms  \
# id
# 0                            42                                 19
# 1                            56                                 20
# 2                            22                                  8
# 3                            71                                 29
# 4                            23                                  9
#
#     de_rhythmscore-de_trackdurationms  de_rhythmscore-qt_energy  \
# id
# 0                                  47                        19
# 1                                  51                        20
# 2                                  21                        10
# 3                                  73                        29
# 4                                  22                        11
#
#     de_energy-de_rhythmscore  de_audioloudness-qt_audioloudness  \
# id
# 0                         48                                  6
# 1                         51                                  0
# 2                         26                                  0
# 3                         74                                 10
# 4                         29                                  1
#
#     qt_audioloudness-qt_vocalcontent  de_vocalcontent-qt_audioloudness  \
# id
# 0                                  6                                14
# 1                                  1                                 2
# 2                                  2                                 4
# 3                                  9                                22
# 4                                  0                                 0
#
#     qt_acousticquality-qt_audioloudness  de_acousticquality-qt_audioloudness  \
# id
# 0                                     8                                   18
# 1                                     3                                    6
# 2                                     1                                    3
# 3                                    12                                   27
# 4                                     0                                    1
#
#     qt_audioloudness-qt_instrumentalscore  \
# id
# 0                                       6
# 1                                       2
# 2                                       2
# 3                                      10
# 4                                       0
#
#     de_instrumentalscore-qt_audioloudness  \
# id
# 0                                      14
# 1                                       6
# 2                                       6
# 3                                      24
# 4                                       0
#
#     qt_audioloudness-qt_liveperformancelikelihood  \
# id
# 0                                               8
# 1                                               2
# 2                                               0
# 3                                              13
# 4                                               3
#
#     de_liveperformancelikelihood-qt_audioloudness  \
# id
# 0                                              18
# 1                                               4
# 2                                               0
# 3                                              28
# 4                                               7
#
#     qt_audioloudness-qt_moodscore  de_moodscore-qt_audioloudness  \
# id
# 0                               9                             22
# 1                               2                              6
# 2                               1                              2
# 3                              12                             31
# 4                               1                              3
#
#     qt_audioloudness-qt_trackdurationms  de_trackdurationms-qt_audioloudness  \
# id
# 0                                    11                                   27
# 1                                     0                                    1
# 2                                     0                                    1
# 3                                    13                                   33
# 4                                     1                                    2
#
#     qt_audioloudness-qt_energy  de_energy-qt_audioloudness  \
# id
# 0                           11                          28
# 1                            0                           1
# 2                            2                           6
# 3                           13                          34
# 4                            3                           9
#
#     de_audioloudness-qt_vocalcontent  de_audioloudness-de_vocalcontent  \
# id
# 0                                 15                                35
# 1                                  1                                 2
# 2                                  2                                 4
# 3                                 24                                57
# 4                                  3                                 7
#
#     de_audioloudness-qt_acousticquality  de_acousticquality-de_audioloudness  \
# id
# 0                                    20                                   45
# 1                                     3                                    6
# 2                                     1                                    3
# 3                                    32                                   72
# 4                                     4                                   10
#
#     de_audioloudness-qt_instrumentalscore  \
# id
# 0                                      15
# 1                                       2
# 2                                       2
# 3                                      25
# 4                                       3
#
#     de_audioloudness-de_instrumentalscore  \
# id
# 0                                      35
# 1                                       6
# 2                                       6
# 3                                      59
# 4                                       7
#
#     de_audioloudness-qt_liveperformancelikelihood  \
# id
# 0                                              20
# 1                                               2
# 2                                               0
# 3                                              33
# 4                                               7
#
#     de_audioloudness-de_liveperformancelikelihood  \
# id
# 0                                              45
# 1                                               4
# 2                                               0
# 3                                              73
# 4                                              16
#
#     de_audioloudness-qt_moodscore  de_audioloudness-de_moodscore  \
# id
# 0                              21                             52
# 1                               2                              6
# 2                               1                              2
# 3                              32                             81
# 4                               5                             13
#
#     de_audioloudness-qt_trackdurationms  de_audioloudness-de_trackdurationms  \
# id
# 0                                    23                                   57
# 1                                     0                                    1
# 2                                     0                                    1
# 3                                    33                                   83
# 4                                     5                                   12
#
#     de_audioloudness-qt_energy  de_audioloudness-de_energy  \
# id
# 0                           23                          58
# 1                            0                           1
# 2                            2                           6
# 3                           33                          84
# 4                            7                          19
#
#     de_vocalcontent-qt_vocalcontent  qt_acousticquality-qt_vocalcontent  \
# id
# 0                                 0                                   0
# 1                                 2                                   7
# 2                                 5                                   9
# 3                                 1                                   0
# 4                                 0                                   0
#
#     de_acousticquality-qt_vocalcontent  qt_instrumentalscore-qt_vocalcontent  \
# id
# 0                                    0                                     0
# 1                                   15                                     5
# 2                                   21                                     8
# 3                                    0                                     1
# 4                                    1                                     0
#
#     de_instrumentalscore-qt_vocalcontent  \
# id
# 0                                      0
# 1                                     13
# 2                                     20
# 3                                      3
# 4                                      0
#
#     qt_liveperformancelikelihood-qt_vocalcontent  \
# id
# 0                                              0
# 1                                              6
# 2                                              8
# 3                                              1
# 4                                              3
#
#     de_liveperformancelikelihood-qt_vocalcontent  \
# id
# 0                                              0
# 1                                             13
# 2                                             18
# 3                                              1
# 4                                              7
#
#     qt_moodscore-qt_vocalcontent  de_moodscore-qt_vocalcontent  \
# id
# 0                              1                             2
# 1                              6                            16
# 2                              9                            22
# 3                              0                             1
# 4                              1                             3
#
#     qt_trackdurationms-qt_vocalcontent  de_trackdurationms-qt_vocalcontent  \
# id
# 0                                    3                                   7
# 1                                    4                                  11
# 2                                    8                                  21
# 3                                    1                                   3
# 4                                    1                                   2
#
#     qt_energy-qt_vocalcontent  de_energy-qt_vocalcontent  \
# id
# 0                           3                          8
# 1                           4                         11
# 2                          10                         26
# 3                           1                          4
# 4                           3                          9
#
#     de_vocalcontent-qt_acousticquality  de_acousticquality-de_vocalcontent  \
# id
# 0                                    0                                   0
# 1                                   11                                  24
# 2                                   17                                  39
# 3                                    4                                   9
# 4                                    0                                   1
#
#     de_vocalcontent-qt_instrumentalscore  \
# id
# 0                                      0
# 1                                      8
# 2                                     14
# 3                                      4
# 4                                      0
#
#     de_instrumentalscore-de_vocalcontent  \
# id
# 0                                      0
# 1                                     20
# 2                                     34
# 3                                     10
# 4                                      0
#
#     de_vocalcontent-qt_liveperformancelikelihood  \
# id
# 0                                              0
# 1                                             10
# 2                                             16
# 3                                              5
# 4                                              3
#
#     de_liveperformancelikelihood-de_vocalcontent  \
# id
# 0                                              0
# 1                                             22
# 2                                             36
# 3                                             10
# 4                                              7
#
#     de_vocalcontent-qt_moodscore  de_moodscore-de_vocalcontent  \
# id
# 0                              1                             2
# 1                             10                            26
# 2                             17                            42
# 3                              4                            11
# 4                              1                             3
#
#     de_vocalcontent-qt_trackdurationms  de_trackdurationms-de_vocalcontent  \
# id
# 0                                    3                                   7
# 1                                    8                                  21
# 2                                   16                                  41
# 3                                    5                                  13
# 4                                    1                                   2
#
#     de_vocalcontent-qt_energy  de_energy-de_vocalcontent  \
# id
# 0                           3                          8
# 1                           8                         21
# 2                          18                         46
# 3                           5                         14
# 4                           3                          9
#
#     de_acousticquality-qt_acousticquality  \
# id
# 0                                       0
# 1                                       8
# 2                                       4
# 3                                       0
# 4                                       1
#
#     qt_acousticquality-qt_instrumentalscore  \
# id
# 0                                         0
# 1                                        11
# 2                                         5
# 3                                         1
# 4                                         0
#
#     de_instrumentalscore-qt_acousticquality  \
# id
# 0                                         0
# 1                                        27
# 2                                        13
# 3                                         3
# 4                                         0
#
#     qt_acousticquality-qt_liveperformancelikelihood  \
# id
# 0                                                 0
# 1                                                14
# 2                                                 4
# 3                                                 1
# 4                                                 3
#
#     de_liveperformancelikelihood-qt_acousticquality  \
# id
# 0                                                 0
# 1                                                31
# 2                                                 9
# 3                                                 1
# 4                                                 7
#
#     qt_acousticquality-qt_moodscore  de_moodscore-qt_acousticquality  \
# id
# 0                                 1                                2
# 1                                14                               36
# 2                                 5                               12
# 3                                 0                                1
# 4                                 1                                3
#
#     qt_acousticquality-qt_trackdurationms  \
# id
# 0                                       3
# 1                                      12
# 2                                       4
# 3                                       1
# 4                                       1
#
#     de_trackdurationms-qt_acousticquality  qt_acousticquality-qt_energy  \
# id
# 0                                       7                             3
# 1                                      31                            12
# 2                                      11                             6
# 3                                       3                             1
# 4                                       2                             3
#
#     de_energy-qt_acousticquality  de_acousticquality-qt_instrumentalscore  \
# id
# 0                              8                                        0
# 1                             31                                       20
# 2                             16                                       11
# 3                              4                                        1
# 4                              9                                        3
#
#     de_acousticquality-de_instrumentalscore  \
# id
# 0                                         0
# 1                                        48
# 2                                        27
# 3                                         3
# 4                                         7
#
#     de_acousticquality-qt_liveperformancelikelihood  \
# id
# 0                                                 0
# 1                                                26
# 2                                                12
# 3                                                 1
# 4                                                 7
#
#     de_acousticquality-de_liveperformancelikelihood  \
# id
# 0                                                 0
# 1                                                58
# 2                                                27
# 3                                                 1
# 4                                                16
#
#     de_acousticquality-qt_moodscore  de_acousticquality-de_moodscore  \
# id
# 0                                 1                                2
# 1                                26                               66
# 2                                13                               32
# 3                                 0                                1
# 4                                 5                               13
#
#     de_acousticquality-qt_trackdurationms  \
# id
# 0                                       3
# 1                                      24
# 2                                      12
# 3                                       1
# 4                                       5
#
#     de_acousticquality-de_trackdurationms  de_acousticquality-qt_energy  \
# id
# 0                                       7                             3
# 1                                      61                            24
# 2                                      31                            14
# 3                                       3                             1
# 4                                      12                             7
#
#     de_acousticquality-de_energy  de_instrumentalscore-qt_instrumentalscore  \
# id
# 0                              8                                          0
# 1                             61                                          7
# 2                             36                                          7
# 3                              4                                          3
# 4                             19                                          0
#
#     qt_instrumentalscore-qt_liveperformancelikelihood  \
# id
# 0                                                   0
# 1                                                  10
# 2                                                   8
# 3                                                   5
# 4                                                   3
#
#     de_liveperformancelikelihood-qt_instrumentalscore  \
# id
# 0                                                   0
# 1                                                  22
# 2                                                  18
# 3                                                  10
# 4                                                   7
#
#     qt_instrumentalscore-qt_moodscore  de_moodscore-qt_instrumentalscore  \
# id
# 0                                   1                                  2
# 1                                  10                                 26
# 2                                   9                                 22
# 3                                   4                                 11
# 4                                   1                                  3
#
#     qt_instrumentalscore-qt_trackdurationms  \
# id
# 0                                         3
# 1                                         8
# 2                                         8
# 3                                         5
# 4                                         1
#
#     de_trackdurationms-qt_instrumentalscore  qt_energy-qt_instrumentalscore  \
# id
# 0                                         7                               3
# 1                                        21                               8
# 2                                        21                              10
# 3                                        13                               5
# 4                                         2                               3
#
#     de_energy-qt_instrumentalscore  \
# id
# 0                                8
# 1                               21
# 2                               26
# 3                               14
# 4                                9
#
#     de_instrumentalscore-qt_liveperformancelikelihood  \
# id
# 0                                                   0
# 1                                                  26
# 2                                                  24
# 3                                                  13
# 4                                                   3
#
#     de_instrumentalscore-de_liveperformancelikelihood  \
# id
# 0                                                   0
# 1                                                  58
# 2                                                  54
# 3                                                  28
# 4                                                   7
#
#     de_instrumentalscore-qt_moodscore  de_instrumentalscore-de_moodscore  \
# id
# 0                                   1                                  2
# 1                                  26                                 66
# 2                                  25                                 62
# 3                                  12                                 31
# 4                                   1                                  3
#
#     de_instrumentalscore-qt_trackdurationms  \
# id
# 0                                         3
# 1                                        24
# 2                                        24
# 3                                        13
# 4                                         1
#
#     de_instrumentalscore-de_trackdurationms  de_instrumentalscore-qt_energy  \
# id
# 0                                         7                               3
# 1                                        61                              24
# 2                                        61                              26
# 3                                        33                              13
# 4                                         2                               3
#
#     de_energy-de_instrumentalscore  \
# id
# 0                                8
# 1                               61
# 2                               66
# 3                               34
# 4                                9
#
#     de_liveperformancelikelihood-qt_liveperformancelikelihood  \
# id
# 0                                                   0
# 1                                                   5
# 2                                                   0
# 3                                                   2
# 4                                                   9
#
#     qt_liveperformancelikelihood-qt_moodscore  \
# id
# 0                                           1
# 1                                          10
# 2                                           1
# 3                                           4
# 4                                          13
#
#     de_moodscore-qt_liveperformancelikelihood  \
# id
# 0                                           2
# 1                                          26
# 2                                           2
# 3                                          11
# 4                                          33
#
#     qt_liveperformancelikelihood-qt_trackdurationms  \
# id
# 0                                                 3
# 1                                                 8
# 2                                                 0
# 3                                                 5
# 4                                                13
#
#     de_trackdurationms-qt_liveperformancelikelihood  \
# id
# 0                                                 7
# 1                                                21
# 2                                                 1
# 3                                                13
# 4                                                32
#
#     qt_energy-qt_liveperformancelikelihood  \
# id
# 0                                        3
# 1                                        8
# 2                                        2
# 3                                        5
# 4                                       15
#
#     de_energy-qt_liveperformancelikelihood  \
# id
# 0                                        8
# 1                                       21
# 2                                        6
# 3                                       14
# 4                                       39
#
#     de_liveperformancelikelihood-qt_moodscore  \
# id
# 0                                           1
# 1                                          18
# 2                                           1
# 3                                           4
# 4                                          29
#
#     de_liveperformancelikelihood-de_moodscore  \
# id
# 0                                           2
# 1                                          46
# 2                                           2
# 3                                          11
# 4                                          73
#
#     de_liveperformancelikelihood-qt_trackdurationms  \
# id
# 0                                                 3
# 1                                                16
# 2                                                 0
# 3                                                 5
# 4                                                29
#
#     de_liveperformancelikelihood-de_trackdurationms  \
# id
# 0                                                 7
# 1                                                41
# 2                                                 1
# 3                                                13
# 4                                                72
#
#     de_liveperformancelikelihood-qt_energy  \
# id
# 0                                        3
# 1                                       16
# 2                                        2
# 3                                        5
# 4                                       31
#
#     de_energy-de_liveperformancelikelihood  de_moodscore-qt_moodscore  \
# id
# 0                                        8                          3
# 1                                       41                          7
# 2                                        6                          3
# 3                                       14                          1
# 4                                       79                          4
#
#     qt_moodscore-qt_trackdurationms  de_trackdurationms-qt_moodscore  \
# id
# 0                                 7                               17
# 1                                 8                               21
# 2                                 4                               11
# 3                                 1                                3
# 4                                 5                               12
#
#     qt_energy-qt_moodscore  de_energy-qt_moodscore  \
# id
# 0                        7                      18
# 1                        8                      21
# 2                        6                      16
# 3                        1                       4
# 4                        7                      19
#
#     de_moodscore-qt_trackdurationms  de_moodscore-de_trackdurationms  \
# id
# 0                                11                               27
# 1                                24                               61
# 2                                 8                               21
# 3                                 5                               13
# 4                                13                               32
#
#     de_moodscore-qt_energy  de_energy-de_moodscore  \
# id
# 0                       11                      28
# 1                       24                      61
# 2                       10                      26
# 3                        5                      14
# 4                       15                      39
#
#     de_trackdurationms-qt_trackdurationms  qt_energy-qt_trackdurationms  \
# id
# 0                                       9                            15
# 1                                       1                             0
# 2                                       1                             2
# 3                                       4                             5
# 4                                       3                             7
#
#     de_energy-qt_trackdurationms  de_trackdurationms-qt_energy  \
# id
# 0                             38                            31
# 1                              1                             4
# 2                              6                             6
# 3                             14                            13
# 4                             19                            11
#
#     de_energy-de_trackdurationms  de_energy-qt_energy
# id
# 0                             78                   10
# 1                             11                    1
# 2                             16                    7
# 3                             34                    5
# 4                             29                   11
# (524164, 186)

# %%
# !rm -r /kaggle/working/AG_beats_models

# %%
from autogluon.tabular import TabularPredictor
from autogluon.core.metrics import make_scorer

## -- RUN 1: Use train data --
predictor = TabularPredictor(
                label = TARGET,
         problem_type = "regression",
          eval_metric = "rmse",
                 path = "./AG_beats_models",
).fit(
                   train_data = train,
                      presets = 'best_quality',
                num_bag_folds = 10,
             dynamic_stacking = False,
             num_stack_levels = 1,
                 # num_bag_sets = 2,
                   time_limit = 3600*11.5,
        # [ 'XGB', 'GBM', 'CAT', 'RF', 'XT', 'FASTAI', 'NN_TORCH']
         # included_model_types = ['RF', 'XT', 'FASTAI'],
                  # ag_args_fit = {'num_cpus': os.cpu_count() - 1},
                     num_gpus = torch.cuda.device_count(),
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Sun Nov 10 10:07:59 UTC 2024
# CPU Count:          4
# Memory Avail:       29.46 GB / 31.35 GB (94.0%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=10, num_bag_sets=1
# Beginning AutoGluon training ... Time limit = 41400s
# AutoGluon will save models to "/kaggle/working/AG_beats_models"
# Train Data Rows:    524164
# Train Data Columns: 185
# Label Column:       BeatsPerMinute
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    30165.83 MB
# 	Train Data (Original)  Memory Usage: 204.45 MB (0.7% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) :  14 | ['RhythmScore', 'AudioLoudness', 'VocalContent', 'AcousticQuality', 'InstrumentalScore', ...]
# 		('int', [])   : 171 | ['qt_rhythmscore', 'de_rhythmscore', 'qt_audioloudness', 'de_audioloudness', 'qt_vocalcontent', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) :  14 | ['RhythmScore', 'AudioLoudness', 'VocalContent', 'AcousticQuality', 'InstrumentalScore', ...]
# 		('int', [])   : 171 | ['qt_rhythmscore', 'de_rhythmscore', 'qt_audioloudness', 'de_audioloudness', 'qt_vocalcontent', ...]
# 	1.6s = Fit runtime
# 	185 features in original data used to generate 185 features in processed data.
# 	Train Data (Processed) Memory Usage: 204.45 MB (0.7% of available memory)
# Data preprocessing and feature engineering runtime = 1.96s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 27591.79s of the 41398.03s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=4.50%)
# 	-26.4638	 = Validation score   (-root_mean_squared_error)
# 	177.56s	 = Training   runtime
# 	3.46s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 27401.75s of the 41207.99s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=4.60%)
# 	-26.4586	 = Validation score   (-root_mean_squared_error)
# 	141.57s	 = Training   runtime
# 	2.41s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 27255.45s of the 41061.69s of remaining time.
# 	-26.5769	 = Validation score   (-root_mean_squared_error)
# 	9380.22s	 = Training   runtime
# 	62.53s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 17810.79s of the 31617.03s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=6.40%)
# 	-26.4605	 = Validation score   (-root_mean_squared_error)
# 	184.64s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 17621.39s of the 31427.62s of remaining time.
# 	-26.5498	 = Validation score   (-root_mean_squared_error)
# 	2329.51s	 = Training   runtime
# 	55.96s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 15234.07s of the 29040.31s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=7.92%)
# 	-26.4634	 = Validation score   (-root_mean_squared_error)
# 	1484.94s	 = Training   runtime
# 	7.92s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 13743.93s of the 27550.17s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=6.36%)
# 	-26.4618	 = Validation score   (-root_mean_squared_error)
# 	130.89s	 = Training   runtime
# 	8.73s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 13607.93s of the 27414.17s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=2, gpus=0, memory=4.33%)
# 	-26.4658	 = Validation score   (-root_mean_squared_error)
# 	2524.25s	 = Training   runtime
# 	4.99s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 11079.80s of the 24886.03s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=5.03%)
# 	-26.4599	 = Validation score   (-root_mean_squared_error)
# 	177.0s	 = Training   runtime
# 	3.34s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 10897.87s of the 24704.10s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=6.40%)
# 	-26.4606	 = Validation score   (-root_mean_squared_error)
# 	122.49s	 = Training   runtime
# 	0.62s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 10770.70s of the 24576.93s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=2, gpus=0, memory=4.33%)
# 	-26.4662	 = Validation score   (-root_mean_squared_error)
# 	4813.78s	 = Training   runtime
# 	5.61s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 5953.03s of the 19759.26s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=4.76%)
# 	-26.4592	 = Validation score   (-root_mean_squared_error)
# 	275.19s	 = Training   runtime
# 	7.4s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 5672.69s of the 19478.93s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=7.93%)
# 	-26.471	 = Validation score   (-root_mean_squared_error)
# 	5988.93s	 = Training   runtime
# 	17.94s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 2759.18s of the 13483.32s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L1': 0.6, 'NeuralNetFastAI_BAG_L1': 0.2, 'LightGBMLarge_BAG_L1': 0.2}
# 	-26.4582	 = Validation score   (-root_mean_squared_error)
# 	0.97s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 13482.31s of the 13482.18s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=5.22%)
# 	-26.4579	 = Validation score   (-root_mean_squared_error)
# 	196.6s	 = Training   runtime
# 	3.22s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 13280.69s of the 13280.57s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=5.22%)
# 	-26.4576	 = Validation score   (-root_mean_squared_error)
# 	178.01s	 = Training   runtime
# 	2.88s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 13097.53s of the 13097.41s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 284 due to low time. Expected time usage reduced from 13789.2s -> 13096.0s...
# 	-26.5127	 = Validation score   (-root_mean_squared_error)
# 	12979.78s	 = Training   runtime
# 	65.75s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 49.97s of the 49.85s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=7.07%)
# 	-26.4673	 = Validation score   (-root_mean_squared_error)
# 	34.72s	 = Training   runtime
# 	0.24s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 10.16s of the 10.03s of remaining time.
# 	Warning: Model is expected to require 3209.1s to train, which exceeds the maximum time limit of 8.4s, skipping model...
# 	Time limit exceeded... Skipping ExtraTreesMSE_BAG_L2.
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 1348.23s of the -35.12s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L2': 0.391, 'LightGBMXT_BAG_L2': 0.217, 'LightGBM_BAG_L1': 0.174, 'RandomForestMSE_BAG_L2': 0.13, 'NeuralNetFastAI_BAG_L1': 0.043, 'LightGBMLarge_BAG_L1': 0.043}
# 	-26.4555	 = Validation score   (-root_mean_squared_error)
# 	1.18s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 41436.72s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 597.8 rows/s (52417 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_beats_models")

# %%
## -- Get Summary -- 
print(f"""
    {'█'*5}| Total models : {len(predictor.model_names())}
    {'█'*5}| Best model   : {predictor.model_best}
        """)

## -- Observe RUN 1 RESULTS --
leaderboard = predictor.leaderboard(silent=True)
display(leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral"))
# Out:
#     █████| Total models : 19
#     █████| Best model   : WeightedEnsemble_L3
# <style type="text/css">
# #T_ff0f6_row0_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_ff0f6_row1_col1 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# #T_ff0f6_row2_col1, #T_ff0f6_row3_col1 {
#   background-color: #555aa7;
#   color: #f1f1f1;
# }
# #T_ff0f6_row4_col1 {
#   background-color: #545ca8;
#   color: #f1f1f1;
# }
# #T_ff0f6_row5_col1 {
#   background-color: #525fa9;
#   color: #f1f1f1;
# }
# #T_ff0f6_row6_col1 {
#   background-color: #4e63ac;
#   color: #f1f1f1;
# }
# #T_ff0f6_row7_col1, #T_ff0f6_row8_col1 {
#   background-color: #4d65ad;
#   color: #f1f1f1;
# }
# #T_ff0f6_row9_col1 {
#   background-color: #486cb0;
#   color: #f1f1f1;
# }
# #T_ff0f6_row10_col1 {
#   background-color: #4273b3;
#   color: #f1f1f1;
# }
# #T_ff0f6_row11_col1 {
#   background-color: #4175b4;
#   color: #f1f1f1;
# }
# #T_ff0f6_row12_col1 {
#   background-color: #3a7eb8;
#   color: #f1f1f1;
# }
# #T_ff0f6_row13_col1 {
#   background-color: #3880b9;
#   color: #f1f1f1;
# }
# #T_ff0f6_row14_col1 {
#   background-color: #3585bb;
#   color: #f1f1f1;
# }
# #T_ff0f6_row15_col1 {
#   background-color: #3f97b7;
#   color: #f1f1f1;
# }
# #T_ff0f6_row16_col1 {
#   background-color: #f8fcb4;
#   color: #000000;
# }
# #T_ff0f6_row17_col1 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_ff0f6_row18_col1 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ff0f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff0f6_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_ff0f6_level0_col1" class="col_heading level0 col1" >score_val</th>
#       <th id="T_ff0f6_level0_col2" class="col_heading level0 col2" >eval_metric</th>
#       <th id="T_ff0f6_level0_col3" class="col_heading level0 col3" >pred_time_val</th>
#       <th id="T_ff0f6_level0_col4" class="col_heading level0 col4" >fit_time</th>
#       <th id="T_ff0f6_level0_col5" class="col_heading level0 col5" >pred_time_val_marginal</th>
#       <th id="T_ff0f6_level0_col6" class="col_heading level0 col6" >fit_time_marginal</th>
#       <th id="T_ff0f6_level0_col7" class="col_heading level0 col7" >stack_level</th>
#       <th id="T_ff0f6_level0_col8" class="col_heading level0 col8" >can_infer</th>
#       <th id="T_ff0f6_level0_col9" class="col_heading level0 col9" >fit_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff0f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff0f6_row0_col0" class="data row0 col0" >WeightedEnsemble_L3</td>
#       <td id="T_ff0f6_row0_col1" class="data row0 col1" >-26.455532</td>
#       <td id="T_ff0f6_row0_col2" class="data row0 col2" >root_mean_squared_error</td>
#       <td id="T_ff0f6_row0_col3" class="data row0 col3" >253.505996</td>
#       <td id="T_ff0f6_row0_col4" class="data row0 col4" >41086.529338</td>
#       <td id="T_ff0f6_row0_col5" class="data row0 col5" >0.006438</td>
#       <td id="T_ff0f6_row0_col6" class="data row0 col6" >1.175491</td>
#       <td id="T_ff0f6_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_ff0f6_row0_col8" class="data row0 col8" >True</td>
#       <td id="T_ff0f6_row0_col9" class="data row0 col9" >19</td>
#     </tr>
#     <tr>
#       <th id="T_ff0f6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ff0f6_row1_col0" class="data row1 col0" >LightGBM_BAG_L2</td>
#       <td id="T_ff0f6_row1_col1" class="data row1 col1" >-26.457625</td>
#       <td id="T_ff0f6_row1_col2" class="data row1 col2" >root_mean_squared_error</td>
#       <td id="T_ff0f6_row1_col3" class="data row1 col3" >184.527936</td>
#       <td id="T_ff0f6_row1_col4" class="data row1 col4" >27908.971387</td>
#       <td id="T_ff0f6_row1_col5" class="data row1 col5" >2.875993</td>
#       <td id="T_ff0f6_row1_col6" class="data row1 col6" >178.007927</td>
#       <td id="T_ff0f6_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_ff0f6_row1_col8" class="data row1 col8" >True</td>
#       <td id="T_ff0f6_row1_col9" class="data row1 col9" >16</td>
#     </tr>
#     <tr>
#       <th id="T_ff0f6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ff0f6_row2_col0" class="data row2 col0" >LightGBMXT_BAG_L2</td>
#       <td id="T_ff0f6_row2_col1" class="data row2 col1" >-26.457932</td>
#       <td id="T_ff0f6_row2_col2" class="data row2 col2" >root_mean_squared_error</td>
#       <td id="T_ff0f6_row2_col3" class="data row2 col3" >184.872226</td>
#       <td id="T_ff0f6_row2_col4" class="data row2 col4" >27927.562378</td>
#       <td id="T_ff0f6_row2_col5" class="data row2 col5" >3.220284</td>
#       <td id="T_ff0f6_row2_col6" class="data row2 col6" >196.598918</td>
#       <td id="T_ff0f6_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_ff0f6_row2_col8" class="data row2 col8" >True</td>
#       <td id="T_ff0f6_row2_col9" class="data row2 col9" >15</td>
#     </tr>
#     <tr>
#       <th id="T_ff0f6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ff0f6_row3_col0" class="data row3 col0" >WeightedEnsemble_L2</td>
#       <td id="T_ff0f6_row3_col1" class="data row3 col1" >-26.458159</td>
#       <td id="T_ff0f6_row3_col2" class="data row3 col2" >root_mean_squared_error</td>
#       <td id="T_ff0f6_row3_col3" class="data row3 col3" >13.689773</td>
#       <td id="T_ff0f6_row3_col4" class="data row3 col4" >1804.470187</td>
#       <td id="T_ff0f6_row3_col5" class="data row3 col5" >0.006740</td>
#       <td id="T_ff0f6_row3_col6" class="data row3 col6" >0.971471</td>
#       <td id="T_ff0f6_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_ff0f6_row3_col8" class="data row3 col8" >True</td>
#       <td id="T_ff0f6_row3_col9" class="data row3 col9" >14</td>
#     </tr>
#     <tr>
#       <th id="T_ff0f6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ff0f6_row4_col0" class="data row4 col0" >LightGBM_BAG_L1</td>
#       <td id="T_ff0f6_row4_col1" class="data row4 col1" >-26.458584</td>
#       <td id="T_ff0f6_row4_col2" class="data row4 col2" >root_mean_squared_error</td>
#       <td id="T_ff0f6_row4_col3" class="data row4 col3" >2.414643</td>
#       <td id="T_ff0f6_row4_col4" class="data row4 col4" >141.566391</td>
#       <td id="T_ff0f6_row4_col5" class="data row4 col5" >2.414643</td>
#       <td id="T_ff0f6_row4_col6" class="data row4 col6" >141.566391</td>
#       <td id="T_ff0f6_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_ff0f6_row4_col8" class="data row4 col8" >True</td>
#       <td id="T_ff0f6_row4_col9" class="data row4 col9" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ff0f6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ff0f6_row5_col0" class="data row5 col0" >LightGBM_r131_BAG_L1</td>
#       <td id="T_ff0f6_row5_col1" class="data row5 col1" >-26.459172</td>
#       <td id="T_ff0f6_row5_col2" class="data row5 col2" >root_mean_squared_error</td>
#       <td id="T_ff0f6_row5_col3" class="data row5 col3" >7.404328</td>
#       <td id="T_ff0f6_row5_col4" class="data row5 col4" >275.187859</td>
#       <td id="T_ff0f6_row5_col5" class="data row5 col5" >7.404328</td>
#       <td id="T_ff0f6_row5_col6" class="data row5 col6" >275.187859</td>
#       <td id="T_ff0f6_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_ff0f6_row5_col8" class="data row5 col8" >True</td>
#       <td id="T_ff0f6_row5_col9" class="data row5 col9" >12</td>
#     </tr>
#     <tr>
#       <th id="T_ff0f6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ff0f6_row6_col0" class="data row6 col0" >LightGBMLarge_BAG_L1</td>
#       <td id="T_ff0f6_row6_col1" class="data row6 col1" >-26.459895</td>
#       <td id="T_ff0f6_row6_col2" class="data row6 col2" >root_mean_squared_error</td>
#       <td id="T_ff0f6_row6_col3" class="data row6 col3" >3.343691</td>
#       <td id="T_ff0f6_row6_col4" class="data row6 col4" >176.997245</td>
#       <td id="T_ff0f6_row6_col5" class="data row6 col5" >3.343691</td>
#       <td id="T_ff0f6_row6_col6" class="data row6 col6" >176.997245</td>
#       <td id="T_ff0f6_row6_col7" class="data row6 col7" >1</td>
#       <td id="T_ff0f6_row6_col8" class="data row6 col8" >True</td>
#       <td id="T_ff0f6_row6_col9" class="data row6 col9" >9</td>
#     </tr>
#     <tr>
#       <th id="T_f

# %%
## -- RUN 2: Use original data as extra learning input --
# predictor.fit_pseudolabel(
#                 orig,
#                 use_ensemble = True,
#                 fit_ensemble = True,
#                 time_limit   = 3600*5,
#                 ag_args_fit  = {'num_cpus': os.cpu_count() - 1},
# )

# %%
## -- Get Summary -- 
# print(f"""
#     # {'█'*5}| Total models : {len(predictor.model_names())}
#     # {'█'*5}| Best model   : {predictor.model_best}
#         """)

# # -- Observe RUN 2 RESULTS --
# leaderboard = predictor.leaderboard(silent=True)
# display(leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral"))

# %%
## -- Create folder directory to save predictions --
NAME_EXT = "_FE185_CPU"
# !mkdir /kaggle/working/AG_beats_predictions{NAME_EXT}
# PREDS_PATH = "/kaggle/working/AG_beats_predictions"

# %%
## -- Make predictions from best model --
pred_df = predictor.predict(test)
pred_df.head()
# Out:
# id
# 524164    119.364517
# 524165    118.867599
# 524166    119.180321
# 524167    118.945641
# 524168    119.028778
# Name: BeatsPerMinute, dtype: float32

# %%
## -- Generate Submission --
FILE_NAME = f"submit_AG{NAME_EXT}.csv"

submit = pd.read_csv(PATH+"sample_submission.csv")
submit[TARGET] = pred_df.values
submit.to_csv(FILE_NAME, index=False)
print(f"{'█'*5}| Submission file {FILE_NAME} saved!")
submit.head(10)
# Out:
# █████| Submission file submit_AG_FE185_CPU.csv saved!
#        id  BeatsPerMinute
# 0  524164      119.364517
# 1  524165      118.867599
# 2  524166      119.180321
# 3  524167      118.945641
# 4  524168      119.028778
# 5  524169      118.833679
# 6  524170      119.184494
# 7  524171      118.517380
# 8  524172      118.853546
# 9  524173      119.043999

# %%
## -- Generate prediction probabilities for all models --
ag_multi_test_proba = predictor.predict_multi(test)

## -- Get TEST PREDICTIONS of all models --
final_test_data = {}

for k, v in tqdm(ag_multi_test_proba.items(), desc="Exporting TEST predictions"):
    k_renamed = k.replace('_', '') + NAME_EXT
    final_test_data[k_renamed] = v

SAVE_PRED = f"/kaggle/working/AG_beats_predictions{NAME_EXT}/pred_ag{NAME_EXT}.parquet"
final_test_df = pd.DataFrame(final_test_data)
final_test_df.to_parquet(SAVE_PRED, index=False)
final_test_df.head()
# Out:
# Exporting TEST predictions:   0%|          | 0/19 [00:00<?, ?it/s]
#         LightGBMXTBAGL1_FE185_CPU  LightGBMBAGL1_FE185_CPU  \
# id
# 524164                 118.939209               119.074265
# 524165                 118.636780               118.570938
# 524166                 119.042503               118.730125
# 524167                 118.828941               119.037949
# 524168                 118.916237               118.950523
#
#         RandomForestMSEBAGL1_FE185_CPU  CatBoostBAGL1_FE185_CPU  \
# id
# 524164                      117.709465               119.021439
# 524165                      117.261787               118.671082
# 524166                      119.962921               119.109116
# 524167                      117.688995               119.035133
# 524168                      120.840874               118.901283
#
#         ExtraTreesMSEBAGL1_FE185_CPU  NeuralNetFastAIBAGL1_FE185_CPU  \
# id
# 524164                    118.159554                      119.031799
# 524165                    117.881432                      118.592957
# 524166                    120.288757                      118.899109
# 524167                    119.701553                      118.888184
# 524168                    119.052246                      118.640396
#
#         XGBoostBAGL1_FE185_CPU  NeuralNetTorchBAGL1_FE185_CPU  \
# id
# 524164              119.278320                     118.867226
# 524165              118.742996                     118.786926
# 524166              119.091934                     118.877769
# 524167              118.889183                     118.896011
# 524168              118.986038                     118.787354
#
#         LightGBMLargeBAGL1_FE185_CPU  CatBoostr177BAGL1_FE185_CPU  \
# id
# 524164                    118.962852                   119.016380
# 524165                    118.388474                   118.676979
# 524166                    118.711754                   119.270546
# 524167                    118.878769                   119.055824
# 524168                    118.990028                   118.983948
#
#         NeuralNetTorchr79BAGL1_FE185_CPU  LightGBMr131BAGL1_FE185_CPU  \
# id
# 524164                        118.867592                   119.120651
# 524165                        118.889915                   118.375648
# 524166                        118.967506                   118.934120
# 524167                        119.093857                   118.939209
# 524168                        118.696823                   118.970924
#
#         NeuralNetFastAIr191BAGL1_FE185_CPU  WeightedEnsembleL2_FE185_CPU  \
# id
# 524164                          119.206772                    119.043495
# 524165                          118.846024                    118.538849
# 524166                          119.248642                    118.760254
# 524167                          119.519005                    118.976166
# 524168                          118.886253                    118.896400
#
#         LightGBMXTBAGL2_FE185_CPU  LightGBMBAGL2_FE185_CPU  \
# id
# 524164                 119.194839               119.180092
# 524165                 118.685707               118.776451
# 524166                 118.979675               118.893784
# 524167                 118.999245               119.146400
# 524168                 118.799805               118.818466
#
#         RandomForestMSEBAGL2_FE185_CPU  CatBoostBAGL2_FE185_CPU  \
# id
# 524164                      120.832329               119.018517
# 524165                      120.091042               119.018517
# 524166                      121.224556               119.024109
# 524167                      118.172386               119.024109
# 524168                      120.288017               119.018517
#
#         WeightedEnsembleL3_FE185_CPU
# id
# 524164                    119.364517
# 524165                    118.867599
# 524166                    119.180321
# 524167                    118.945641
# 524168                    119.028778

# %%
## -- Get OOF predictions of all models --
ag_multi_oof_preds = {}
for model in tqdm(predictor.model_names(), desc="Processing OOF probabilities"):
    ag_multi_oof_preds[model] = predictor.predict_oof(
                                         model = model,
                                    train_data = train
                                )

final_oof_data = {}
for k, v in tqdm(ag_multi_oof_preds.items(), desc="Exporting OOF predictions"):
    k_renamed = k.replace('_', '') + NAME_EXT
    final_oof_data[k_renamed] = v
    
SAVE_OOF = f"/kaggle/working/AG_beats_predictions{NAME_EXT}/oof_ag{NAME_EXT}.parquet"
final_oof_df = pd.DataFrame(final_oof_data)
final_oof_df.to_parquet(SAVE_OOF, index=False)
final_oof_df.head()
# Out:
# Processing OOF probabilities:   0%|          | 0/19 [00:00<?, ?it/s]
# Exporting OOF predictions:   0%|          | 0/19 [00:00<?, ?it/s]
#     LightGBMXTBAGL1_FE185_CPU  LightGBMBAGL1_FE185_CPU  \
# id
# 0                  118.491295               118.599380
# 1                  119.053902               118.917580
# 2                  118.293907               119.007111
# 3                  118.524086               118.708694
# 4                  118.827209               119.067085
#
#     RandomForestMSEBAGL1_FE185_CPU  CatBoostBAGL1_FE185_CPU  \
# id
# 0                       117.932777               118.689568
# 1                       115.465248               118.928055
# 2                       123.752296               119.041290
# 3                       117.177872               118.933258
# 4                       119.339447               118.912933
#
#     ExtraTreesMSEBAGL1_FE185_CPU  NeuralNetFastAIBAGL1_FE185_CPU  \
# id
# 0                     118.968124                      118.436104
# 1                     115.327782                      118.896713
# 2                     123.891212                      119.000679
# 3                     119.511612                      118.828751
# 4                     119.835953                      118.403221
#
#     XGBoostBAGL1_FE185_CPU  NeuralNetTorchBAGL1_FE185_CPU  \
# id
# 0               118.792839                     118.549179
# 1               119.024727                     118.988678
# 2               119.001076                     118.876595
# 3               119.015236                     118.989182
# 4               119.133965                     118.569740
#
#     LightGBMLargeBAGL1_FE185_CPU  CatBoostr177BAGL1_FE185_CPU  \
# id
# 0                     118.704475                   118.701500
# 1                     118.688255                   119.039200
# 2                     119.044250                   118.930321
# 3                     118.686707                   118.939606
# 4                     119.289803                   118.816811
#
#     NeuralNetTorchr79BAGL1_FE185_CPU  LightGBMr131BAGL1_FE185_CPU  \
# id
# 0                         119.229691                   118.739235
# 1                         118.869682                   118.718689
# 2                         118.825409                   119.112862
# 3                         118.935432                   118.541626
# 4                         118.961365                   119.102196
#
#     NeuralNetFastAIr191BAGL1_FE185_CPU  WeightedEnsembleL2_FE185_CPU  \
# id
# 0                           119.064362                    118.587746
# 1                           119.458893                    118.867538
# 2                           118.863052                    119.013260
# 3                           118.745918                    118.728310
# 4                           119.276772                    118.978859
#
#     LightGBMXTBAGL2_FE185_CPU  LightGBMBAGL2_FE185_CPU  \
# id
# 0                  118.708725               118.819679
# 1                  119.090546               118.977921
# 2                  118.908646               118.909668
# 3                  118.715065               118.688980
# 4                  118.641029               118.973389
#
#     RandomForestMSEBAGL2_FE185_CPU  CatBoostBAGL2_FE185_CPU  \
# id
# 0                       116.463470               119.022179
# 1                       121.242340               119.023438
# 2                       119.424278               119.015526
# 3                       119.788727               119.022079
# 4                       118.201996               119.016220
#
#     WeightedEnsembleL3_FE185_CPU
# id
# 0                     118.428223
# 1                     119.271141
# 2                     119.003319
# 3                     118.847504
# 4                     118.805779

# %%
predictor.plot_ensemble_model(filename='ensemble_model.png')
display(Image('./AG_beats_models/ensemble_model.png'))

# %%
# !zip -r /kaggle/working/AG_beats_models /kaggle/working/AG_beats_models.zip
# !zip -r AG_beats_predictions{NAME_EXT}.zip /kaggle/working/AG_beats_predictions{NAME_EXT}
# Out:
#   adding: kaggle/working/AG_beats_predictions_FE185_CPU/ (stored 0%)
#   adding: kaggle/working/AG_beats_predictions_FE185_CPU/pred_ag_FE185_CPU.parquet (deflated 13%)
#   adding: kaggle/working/AG_beats_predictions_FE185_CPU/oof_ag_FE185_CPU.parquet (deflated 11%)

# %%
## -- EXTRACT MODEL AND SCORES --
result_dict = dict(zip(leaderboard['model'], leaderboard['score_val']))
result_df = pd.DataFrame.from_dict(result_dict, orient='index').sort_values(0)

max_score = result_df.max().item()
min_score = result_df.min().item()

## -- PLOT MODELS & SCORES --
plt.figure(figsize=(18, 10))
plt.stem(
    result_df.index,
    result_df[0],
    orientation = 'horizontal',
    bottom = min_score - 0.0055,
    markerfmt = 'C3o'
)
plt.xlim(min_score - 0.006, max_score + 0.03)
plt.xlabel('Score (RMSE)')
plt.title('-- RMSE (OOF Predictions) --', fontsize=15)

for i, value in enumerate(result_df[0]):
    plt.text(value+1e-3, i, f'{abs(value):.5f}', ha='left', va='center')

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
## -- OPTIONAL: Remove stored files --
# !rm -r /kaggle/working/AG_beats_models
# !rm -r /kaggle/working/AG_beats_predictions{NAME_EXT}

# %%
print(f"""
{'-'*48}
{'█'*5} | - AUTOGLUON NOTEBOOK COMPLETE! - | {'█'*5}
{'-'*48}
""")
# Out:
# ------------------------------------------------
# █████ | - AUTOGLUON NOTEBOOK COMPLETE! - | █████
# ------------------------------------------------
