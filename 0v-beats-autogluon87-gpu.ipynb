# %%
# %%capture
# !pip install ipywidgets
# !pip install autogluon scikit-learn==1.5.2

# %%
# %%capture
# !apt-get install -y graphviz graphviz-dev && pip install pydot
# !pip install pygraphviz

# %%
import torch
import os
import pydot

import numpy as np
import pandas as pd
from time import time
from tqdm.auto import tqdm
from itertools import combinations

from IPython.display import display, Image
import matplotlib.pyplot as plt
import seaborn as sns
import bokeh
import shap

import warnings

warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')

pd.options.mode.copy_on_write = True
pd.set_option('display.max_columns', 1000)
# plt.style.use("ggplot")
# sns.set_style("whitegrid")

## -- Ansi color codes --
COLOR = '\033[32m'
RESET = '\033[0m'

# %%
PATH       = "/kaggle/input/playground-series-s5e9/"
train      = pd.read_csv(PATH + "train.csv", index_col='id') #.drop('id', axis=1)
test       = pd.read_csv(PATH + "test.csv", index_col='id') #.drop('id', axis=1)

orig       = pd.read_csv("/kaggle/input/bpm-prediction-challenge/Train.csv")
orig['id'] = np.arange(len(orig))
orig       = orig.set_index('id')

submit     = pd.read_csv(PATH+"sample_submission.csv")

TARGET     = "BeatsPerMinute"
FEATURES   = test.columns.tolist()

LEN_TRAIN  = len(train)
LEN_TEST   = len(test)
LEN_ORIG   = len(orig)

# %%
def distplots_data(
                    train: pd.DataFrame,
                    test: pd.DataFrame,
                    orig: pd.DataFrame,
                    features: list[str]):

    df = pd.concat([train[features].assign(Source = 'Train'), 
                    test[features].assign(Source = 'Test'),
                    orig[features].assign(Source = 'Original'),], 
                    axis=0, ignore_index = True)

    fig, axs = plt.subplots(len(features), 2 ,figsize = (18, len(features) * 4), 
                            gridspec_kw = {
                                            'hspace': 0.2, 
                                            'wspace': 0.15, 
                                            'width_ratios': [0.7, 0.3]
                                    }
                    )
    PALETTE = ['g', 'r', 'orange']
    for i, col in enumerate(features):
        ax = axs[i, 0]
        sns.kdeplot(data = df[[col, 'Source']], x = col, hue = 'Source', 
                    palette = PALETTE, ax = ax, linewidth = 2
                   )
        ax.set(xlabel = '', ylabel = '')
        ax.set_title(f"\n{col}")
        ax.grid()

        ax = axs[i, 1]
        sns.boxplot(data = df, y=col, x=df['Source'], width = 0.5,
                    linewidth = 1, fliersize= 1, ax = ax, palette = PALETTE)
        ax.set_title(f"\n{col}")
        ax.set(xlabel = '', ylabel = '')
        ax.tick_params(axis='both', which='major')
        ax.set_xticklabels(['Train', 'Test', 'Original'])

    plt.tight_layout()
    plt.show()

# %%
distplots_data(train, test, orig, FEATURES)

# %%
# ## -- CREATE FEATURES -- ##
# def create_features(train, test):
#     train = train.copy()
#     test  = test.copy()
#     ## -- Feature 1: Use original as features
#     ORIG_FEATURES = []
#     print(f"Merging {len(FEATURES)} features... ", end="")
#     for c in FEATURES:
#         tmp = orig.groupby(c)[TARGET].mean()
#         n = f"orig_{c}"
#         print(f"{n}, ",end="")
#         tmp.name = n
#         train = train.merge(tmp, on=c, how='left')
#         test = test.merge(tmp, on=c, how='left')
#         ORIG_FEATURES.append(n)
        
#     print()

#     # Feature 2: Scaling
#     for df in [train, test]:
#         df["TrackDurationMin"] = df["TrackDurationMs"] / 60000
#         df["log_AcousticQuality"] = np.log1p(df["AcousticQuality"]).astype('float32')
#         df["sqrt_InstrumentalScore"] = np.sqrt(df["InstrumentalScore"]).astype('float32')
#         df["sqrt_VocalContent"] = np.sqrt(df["VocalContent"]).astype('float32')
#         df["sqrt_LivePerformance"] = np.sqrt(df["LivePerformanceLikelihood"]).astype('float32')

#         df["orig_TrackDurationMin"] = df["orig_TrackDurationMs"] / 60000
#         df["log_orig_AcousticQuality"] = np.log1p(df["orig_AcousticQuality"]).astype('float32')
#         df["sqrt_orig_InstrumentalScore"] = np.sqrt(df["orig_InstrumentalScore"]).astype('float32')
#         df["sqrt_orig_VocalContent"] = np.sqrt(df["orig_VocalContent"]).astype('float32')
#         df["sqrt_orig_LivePerformance"] = np.sqrt(df["orig_LivePerformanceLikelihood"]).astype('float32')

#     # ## -- Feature 3: Interactions
#     # X_INTERACTS = []
#     # D_INTERACTS = []
#     # for n in [2]:
#     #     for cols in tqdm(list(combinations(FEATURES, n)), desc="Creating interactions"):
#     #         ## -- Multiplication
#     #         n1 = '_x_'.join(sorted(cols))
#     #         train[n1] = (train[cols[0]] * train[cols[1]]).astype('float32')
#     #         test[n1] = (test[cols[0]] * test[cols[1]]).astype('float32')
#     #         Division
#     #         n2 = '_/_'.join(sorted(cols))
#     #         train[n2] = (train[cols[0]] / (train[cols[1]] + 1e-6)).astype('float32')
#     #         test[n2] = (test[cols[0]] / (test[cols[1]] + 1e-6)).astype('float32')
#     #         ## -- Inverse Division
#     #         n3 = '_\_'.join(sorted(cols))
#     #         train[n3] = (train[cols[1]] / (train[cols[0]] + 1e-6)).astype('float32')
#     #         test[n3] = (test[cols[1]] / (test[cols[0]] + 1e-6)).astype('float32')

#     #         ## -- X_INTERACTS.append(n1)
#     #         D_INTERACTS.append(n2)
#     #         D_INTERACTS.append(n3)
    
#     ## -- Feature 4: Quartile and Decile features
#     QT = 4
#     DE = 10
#     BINS = []
    
#     print(f"-> Creating {QT} & {DE} bins:")
#     for i, col in enumerate(FEATURES, 1):
#         print(f"Feat_{i}.. ", end="")

#         # Calculate quantiles based on the training set
#         QT_TRAIN = pd.qcut(train[col], q=QT, labels=False, duplicates='drop')
#         DE_TRAIN = pd.qcut(train[col], q=DE, labels=False, duplicates='drop')
        
#         QUAD = f"qt_{col.lower()}"
#         DECI  = f"de_{col.lower()}"
#         # Add binned features to train
#         train[QUAD] = QT_TRAIN
#         train[DECI] = DE_TRAIN

#         # Use the training quantiles to bin the test set
#         QT_BINS = train[col].quantile(np.linspace(0, 1, QT+1))
#         DE_BINS = train[col].quantile(np.linspace(0, 1, DE+1))
        
#         EXTRA = dict(labels=False, include_lowest=True, duplicates='drop')
        
#         test[QUAD] = pd.cut(test[col], bins=QT_BINS, **EXTRA)
#         test[DECI] = pd.cut(test[col], bins=DE_BINS, **EXTRA)

#         # Handle cases where pd.cut returns NaN
#         test[QUAD] = test[QUAD].fillna(-1)
#         test[DECI] = test[DECI].fillna(-1)

#         BINS.append(QUAD)
#         BINS.append(DECI)

#     # Feature 5: Pairwise combinations
#     TE_columns = []
#     for n in [2]:
#         for cols in tqdm(list(combinations(BINS, n)), desc="Creating combinations"):
#             name = '-'.join(sorted(cols))

#             # Create combos by concatenating string representations
#             train[name] = train[cols[0]].astype(str) + '_' + train[cols[1]].astype(str)
#             test[name] = test[cols[0]].astype(str) + '_' + test[cols[1]].astype(str)

#             # if n == 3: # --> Create 3-combo
#             #     train[name] += '_' + train[cols[2]].astype(str)
#             #     test[name] += '_' + test[cols[2]].astype(str)

#             # Fit the category encoder ONLY on the training data
#             train[name] = train[name].astype('category')
#             cat = train[name].cat
#             # Apply consistent encoding across datasets
#             train[name] = train[name].cat.codes
#             # Use the fitted category to transform the test and original sets
#             test[name] = pd.Categorical(test[name], categories=cat.categories).codes

#             TE_columns.append(name)

        
#     ##### ===================== ORIGINAL DATA OPERATIONS ======================== ###
#     orig_BINS = []
    
#     print(f"-> Creating {QT} & {DE} bins - ORIGNAL:")
#     for i, col in enumerate(ORIG_FEATURES, 1):
#         print(f"Feat_{i}.. ", end="")

#         # Calculate quantiles based on the training set
#         QT_TRAIN = pd.qcut(train[col], q=QT, labels=False, duplicates='drop')
#         DE_TRAIN = pd.qcut(train[col], q=DE, labels=False, duplicates='drop')
        
#         QUAD = f"qt_{col.lower()}"
#         DECI  = f"de_{col.lower()}"
#         # Add binned features to train
#         train[QUAD] = QT_TRAIN
#         train[DECI] = DE_TRAIN

#         # Use the training quantiles to bin the test set
#         QT_BINS = train[col].quantile(np.linspace(0, 1, QT+1))
#         DE_BINS = train[col].quantile(np.linspace(0, 1, DE+1))
        
#         EXTRA = dict(labels=False, include_lowest=True, duplicates='drop')
        
#         test[QUAD] = pd.cut(test[col], bins=QT_BINS, **EXTRA)
#         test[DECI] = pd.cut(test[col], bins=DE_BINS, **EXTRA)

#         # Handle cases where pd.cut returns NaN
#         test[QUAD] = test[QUAD].fillna(-1)
#         test[DECI] = test[DECI].fillna(-1)

#         orig_BINS.append(QUAD)
#         orig_BINS.append(DECI)
    
#     # Feature 5: Pairwise combinations
#     orig_TE_columns = []
#     for n in [2]:
#         for cols in tqdm(list(combinations(orig_BINS, n)), desc="Creating combinations -  ORIGINAL"):
#             name = '-'.join(sorted(cols))

#             # Create combos by concatenating string representations
#             train[name] = train[cols[0]].astype(str) + '_' + train[cols[1]].astype(str)
#             test[name] = test[cols[0]].astype(str) + '_' + test[cols[1]].astype(str)

#             # if n == 3: # --> Create 3-combo
#             #     train[name] += '_' + train[cols[2]].astype(str)
#             #     test[name] += '_' + test[cols[2]].astype(str)

#             # Fit the category encoder ONLY on the training data
#             train[name] = train[name].astype('category')
#             cat = train[name].cat
#             # Apply consistent encoding across datasets
#             train[name] = train[name].cat.codes
#             # Use the fitted category to transform the test and original sets
#             test[name] = pd.Categorical(test[name], categories=cat.categories).codes

#             orig_TE_columns.append(name)
            
#     print("Feature Engineering Complete!!!")
#     print(f"-> Binned features   : {len(BINS+orig_BINS)}")
#     print(f"-> Combinations (TE) : {len(TE_columns+orig_TE_columns)}")
#     print(f"---> TOTAL FEATURES  : {len(test.columns)}")

#     return train, test

# %%
## -- CREATE FEATURES -- ##
def create_features(train, test, orig):
    # Feature 1: Scaling
    combine = pd.concat([train, test, orig], ignore_index=True)
    print("Combine shape:", combine.shape)
    
    combine["TrackDurationMin"] = combine["TrackDurationMs"] / 60000
    combine["log_AcousticQuality"] = np.log1p(combine["AcousticQuality"])
    combine["sqrt_InstrumentalScore"] = np.sqrt(combine["InstrumentalScore"])
    combine["sqrt_VocalContent"] = np.sqrt(combine["VocalContent"])
    combine["sqrt_LivePerformance"] = np.sqrt(combine["LivePerformanceLikelihood"])

    DIGITS = []
    for c in ['Energy', 'MoodScore', 'AcousticQuality']:
        for k in range(1,10):
            n = f'{c}_d{k}'
            combine[n] = ((combine[c] * 10**k) % 10).fillna(-1).astype("int8")
            DIGITS.append(n)

    ROUND = []
    RR = [9, 8]
    for c in FEATURES:
        print(f"{c}, ",end="")
        for r in RR:
            n = f"{c}_r{r}"
            combine[n] = combine[c].round(r)
            ROUND.append(n)

    train = combine.iloc[:len(train)]
    test = combine.iloc[len(train):len(train)+len(test)]
    test = test.drop('BeatsPerMinute', axis=1)
    orig = combine.iloc[-len(orig):]
    print()
    
    TE_columns = []
    print(f"Processing {len(FEATURES+ROUND)} features... ",end="")
    for c in FEATURES+ROUND:
        tmp = orig.groupby(c)[TARGET].mean()
        n = f"TE0_{c}"
        print(f"{n}, ",end="")
        tmp.name = n
        train = train.merge(tmp, on=c, how='left')
        test = test.merge(tmp, on=c, how='left')
        TE_columns.append(n)

    print(f"\n{COLOR}-> Total Features: {len(test.columns)}")
    return train, test
    
train, test = create_features(train, test, orig)
# Out:
# Combine shape: (713519, 10)
# RhythmScore, AudioLoudness, VocalContent, AcousticQuality, InstrumentalScore, LivePerformanceLikelihood, MoodScore, TrackDurationMs, Energy,
# Processing 27 features... TE0_RhythmScore, TE0_AudioLoudness, TE0_VocalContent, TE0_AcousticQuality, TE0_InstrumentalScore, TE0_LivePerformanceLikelihood, TE0_MoodScore, TE0_TrackDurationMs, TE0_Energy, TE0_RhythmScore_r9, TE0_RhythmScore_r8, TE0_AudioLoudness_r9, TE0_AudioLoudness_r8, TE0_VocalContent_r9, TE0_VocalContent_r8, TE0_AcousticQuality_r9, TE0_AcousticQuality_r8, TE0_InstrumentalScore_r9, TE0_InstrumentalScore_r8, TE0_LivePerformanceLikelihood_r9, TE0_LivePerformanceLikelihood_r8, TE0_MoodScore_r9, TE0_MoodScore_r8, TE0_TrackDurationMs_r9, TE0_TrackDurationMs_r8, TE0_Energy_r9, TE0_Energy_r8,
# -> Total Features: 86

# %%
display(train.head())
train.shape
# Out:
#    RhythmScore  AudioLoudness  VocalContent  AcousticQuality  \
# 0     0.603610      -7.636942      0.023500         0.000005
# 1     0.639451     -16.267598      0.071520         0.444929
# 2     0.514538     -15.953575      0.110715         0.173699
# 3     0.734463      -1.357000      0.052965         0.001651
# 4     0.532968     -13.056437      0.023500         0.068687
#
#    InstrumentalScore  LivePerformanceLikelihood  MoodScore  TrackDurationMs  \
# 0           0.000001                   0.051385   0.409866      290715.6450
# 1           0.349414                   0.170522   0.651010      164519.5174
# 2           0.453814                   0.029576   0.423865      174495.5667
# 3           0.159717                   0.086366   0.278745      225567.4651
# 4           0.000001                   0.331345   0.477769      213960.6789
#
#      Energy  BeatsPerMinute  TrackDurationMin  log_AcousticQuality  \
# 0  0.826267       147.53020          4.845261             0.000005
# 1  0.145400       136.15963          2.741992             0.368060
# 2  0.624667        55.31989          2.908259             0.160160
# 3  0.487467       147.91212          3.759458             0.001649
# 4  0.947333        89.58511          3.566011             0.066431
#
#    sqrt_InstrumentalScore  sqrt_VocalContent  sqrt_LivePerformance  Energy_d1  \
# 0                0.001034           0.153297              0.226684          8
# 1                0.591113           0.267431              0.412944          1
# 2                0.673657           0.332738              0.171976          6
# 3                0.399646           0.230140              0.293881          4
# 4                0.001034           0.153297              0.575626          9
#
#    Energy_d2  Energy_d3  Energy_d4  Energy_d5  Energy_d6  Energy_d7  \
# 0          2          6          2          6          6          6
# 1          4          5          4          0          0          0
# 2          2          4          6          6          6          6
# 3          8          7          4          6          6          6
# 4          4          7          3          3          3          3
#
#    Energy_d8  Energy_d9  MoodScore_d1  MoodScore_d2  MoodScore_d3  \
# 0          6          7             4             0             9
# 1          0          0             6             5             1
# 2          6          7             4             2             3
# 3          6          7             2             7             8
# 4          3          3             4             7             7
#
#    MoodScore_d4  MoodScore_d5  MoodScore_d6  MoodScore_d7  MoodScore_d8  \
# 0             8             6             6             2             5
# 1             0             1             0             2             5
# 2             8             6             4             9             6
# 3             7             4             5             2             0
# 4             7             6             9             1             0
#
#    MoodScore_d9  AcousticQuality_d1  AcousticQuality_d2  AcousticQuality_d3  \
# 0             9                   0                   0                   0
# 1             2                   4                   4                   4
# 2             0                   1                   7                   3
# 3             2                   0                   0                   1
# 4             1                   0                   6                   8
#
#    AcousticQuality_d4  AcousticQuality_d5  AcousticQuality_d6  \
# 0                   0                   0                   5
# 1                   9                   2                   9
# 2                   6                   9                   8
# 3                   6                   5                   0
# 4                   6                   8                   6
#
#    AcousticQuality_d7  AcousticQuality_d8  AcousticQuality_d9  RhythmScore_r9  \
# 0                   3                   6                   0        0.603610
# 1                   0                   7                   2        0.639451
# 2                   6                   4                   5        0.514538
# 3                   8                   3                   7        0.734463
# 4                   9                   6                   7        0.532968
#
#    RhythmScore_r8  AudioLoudness_r9  AudioLoudness_r8  VocalContent_r9  \
# 0        0.603610         -7.636942         -7.636942         0.023500
# 1        0.639451        -16.267598        -16.267598         0.071520
# 2        0.514538        -15.953575        -15.953575         0.110715
# 3        0.734463         -1.357000         -1.357000         0.052965
# 4        0.532968        -13.056437        -13.056437         0.023500
#
#    VocalContent_r8  AcousticQuality_r9  AcousticQuality_r8  \
# 0         0.023500            0.000005            0.000005
# 1         0.071519            0.444929            0.444929
# 2         0.110715            0.173699            0.173699
# 3         0.052965            0.001651            0.001651
# 4         0.023500            0.068687            0.068687
#
#    InstrumentalScore_r9  InstrumentalScore_r8  LivePerformanceLikelihood_r9  \
# 0              0.000001              0.000001                      0.051385
# 1              0.349414              0.349414                      0.170522
# 2              0.453814              0.453814                      0.029576
# 3              0.159717              0.159717                      0.086366
# 4              0.000001              0.000001                      0.331345
#
#    LivePerformanceLikelihood_r8  MoodScore_r9  MoodScore_r8  \
# 0                      0.051385      0.409866      0.409866
# 1                      0.170522      0.651010      0.651010
# 2                      0.029576      0.423865      0.423865
# 3                      0.086366      0.278745      0.278745
# 4                      0.331345      0.477769      0.477769
#
#    TrackDurationMs_r9  TrackDurationMs_r8  Energy_r9  Energy_r8  \
# 0         290715.6450         290715.6450   0.826267   0.826267
# 1         164519.5174         164519.5174   0.145400   0.145400
# 2         174495.5667         174495.5667   0.624667   0.624667
# 3         225567.4651         225567.4651   0.487467   0.487467
# 4         213960.6789         213960.6789   0.947333   0.947333
#
#    TE0_RhythmScore  TE0_AudioLoudness  TE0_VocalContent  TE0_AcousticQuality  \
# 0       128.943777         103.670696        119.570449           118.492798
# 1              NaN                NaN               NaN                  NaN
# 2       159.284538         111.784954        134.719175           104.163991
# 3        55.768044         120.369246        107.967941           119.076562
# 4              NaN                NaN        119.570449                  NaN
#
#    TE0_InstrumentalScore  TE0_LivePerformanceLikelihood  TE0_MoodScore  \
# 0             118.792949                     138.557926     139.722601
# 1                    NaN                            NaN            NaN
# 2             112.953866                      94.881051     119.429846
# 3             147.602331                     104.047395      85.263665
# 4             118.792949                            NaN            NaN
#
#    TE0_TrackDurationMs  TE0_Energy  TE0_RhythmScore_r9  TE0_RhythmScore_r8  \
# 0                  NaN  137.242701          128.943777          128.943777
# 1                  NaN   86.963370                 NaN                 NaN
# 2           131.578397  160.729156          159.284538          159.284538
# 3                  NaN   59.022426           55.768044           55.768044
# 4                  NaN   53.560673                 NaN                 NaN
#
#    TE0_AudioLoudness_r9  TE0_AudioLoudness_r8  TE0_VocalContent_r9  \
# 0            103.670696            103.670696           119.570449
# 1                   NaN                   NaN                  NaN
# 2            111.784954            111.784954           134.719175
# 3            120.369246            120.369246           107.967941
# 4                   NaN                   NaN           119.570449
#
#    TE0_VocalContent_r8  TE0_AcousticQuality_r9  TE0_AcousticQuality_r8  \
# 0           119.570449              118.492798              118.492798
# 1                  NaN                     NaN                     NaN
# 2           134.719175              104.163991              104.163991
# 3           107.967941              119.076562              119.076562
# 4           119.570449                     NaN                     NaN
#
#    TE0_InstrumentalScore_r9  TE0_InstrumentalScore_r8  \
# 0                118.792949                118.792949
# 1                       NaN                       NaN
# 2                112.953866                112.953866
# 3                147.602331                147.602331
# 4                118.792949                118.792949
#
#    TE0_LivePerformanceLikelihood_r9  TE0_LivePerformanceLikelihood_r8  \
# 0                        138.557926                        138.557926
# 1                               NaN                               NaN
# 2                         94.881051                         94.881051
# 3                        104.047395                        104.047395
# 4                               NaN                               NaN
#
#    TE0_MoodScore_r9  TE0_MoodScore_r8  TE0_TrackDurationMs_r9  \
# 0        139.722601        139.722601                     NaN
# 1               NaN               NaN                     NaN
# 2        119.429846        119.429846              131.578397
# 3         85.263665         85.263665                     NaN
# 4               NaN               NaN                     NaN
#
#    TE0_TrackDurationMs_r8  TE0_Energy_r9  TE0_Energy_r8
# 0                     NaN     137.242701     137.242701
# 1                     NaN      86.963370      86.963370
# 2              131.578397     160.729156     160.729156
# 3                     NaN      59.022426      59.022426
# 4                     NaN      53.560673      53.560673
# (524164, 87)

# %%
# !rm -r /kaggle/working/AG_beats_models

# %%
from autogluon.tabular import TabularPredictor
from autogluon.core.metrics import make_scorer

## -- RUN 1: Use train data --
predictor = TabularPredictor(
                label = TARGET,
         problem_type = "regression",
          eval_metric = "rmse",
                 path = "./AG_beats_models",
).fit(
                   train_data = train,
                      presets = 'best_quality',
                num_bag_folds = 10,
             dynamic_stacking = False,
             num_stack_levels = 1,
                 # num_bag_sets = 2,
                   time_limit = 3600*11,
        # [ 'XGB', 'GBM', 'CAT', 'RF', 'XT', 'FASTAI', 'NN_TORCH']
         # included_model_types = ['RF', 'XT', 'FASTAI'],
                  # ag_args_fit = {'num_cpus': os.cpu_count() - 1},
                     num_gpus = torch.cuda.device_count(),
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.11.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Sun Nov 10 10:07:59 UTC 2024
# CPU Count:          4
# Memory Avail:       29.48 GB / 31.35 GB (94.0%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=10, num_bag_sets=1
# Beginning AutoGluon training ... Time limit = 39600s
# AutoGluon will save models to "/kaggle/working/AG_beats_models"
# Train Data Rows:    524164
# Train Data Columns: 86
# Label Column:       BeatsPerMinute
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    30165.06 MB
# 	Train Data (Original)  Memory Usage: 249.44 MB (0.8% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 14): ['RhythmScore_r9', 'VocalContent_r9', 'TrackDurationMs_r9', 'TrackDurationMs_r8', 'TE0_RhythmScore_r9', 'TE0_AudioLoudness_r9', 'TE0_VocalContent_r9', 'TE0_AcousticQuality_r9', 'TE0_InstrumentalScore_r9', 'TE0_LivePerformanceLikelihood_r9', 'TE0_MoodScore_r9', 'TE0_TrackDurationMs_r9', 'TE0_TrackDurationMs_r8', 'TE0_Energy_r9']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('float', []) : 14 | ['RhythmScore_r9', 'VocalContent_r9', 'TrackDurationMs_r9', 'TrackDurationMs_r8', 'TE0_RhythmScore_r9', ...]
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 45 | ['RhythmScore', 'AudioLoudness', 'VocalContent', 'AcousticQuality', 'InstrumentalScore', ...]
# 		('int', [])   : 27 | ['Energy_d1', 'Energy_d2', 'Energy_d3', 'Energy_d4', 'Energy_d5', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 45 | ['RhythmScore', 'AudioLoudness', 'VocalContent', 'AcousticQuality', 'InstrumentalScore', ...]
# 		('int', [])   : 27 | ['Energy_d1', 'Energy_d2', 'Energy_d3', 'Energy_d4', 'Energy_d5', ...]
# 	5.7s = Fit runtime
# 	72 features in original data used to generate 72 features in processed data.
# 	Train Data (Processed) Memory Usage: 193.45 MB (0.6% of available memory)
# Data preprocessing and feature engineering runtime = 6.15s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 26389.30s of the 39593.84s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=4.14%)
# 	-26.459	 = Validation score   (-root_mean_squared_error)
# 	88.79s	 = Training   runtime
# 	3.48s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 26287.39s of the 39491.93s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=4.23%)
# 	-26.4584	 = Validation score   (-root_mean_squared_error)
# 	73.96s	 = Training   runtime
# 	2.07s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 26208.74s of the 39413.28s of remaining time.
# 	-26.508	 = Validation score   (-root_mean_squared_error)
# 	5519.19s	 = Training   runtime
# 	38.27s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 20649.43s of the 33853.97s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=5.74%)
# 	-26.4586	 = Validation score   (-root_mean_squared_error)
# 	155.19s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 20489.56s of the 33694.10s of remaining time.
# 	-26.4919	 = Validation score   (-root_mean_squared_error)
# 	832.92s	 = Training   runtime
# 	33.39s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 19621.48s of the 32826.02s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=7.41%)
# 	-26.4677	 = Validation score   (-root_mean_squared_error)
# 	1132.19s	 = Training   runtime
# 	6.95s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 18484.09s of the 31688.63s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=5.66%)
# 	-26.4594	 = Validation score   (-root_mean_squared_error)
# 	74.88s	 = Training   runtime
# 	4.71s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 18404.39s of the 31608.93s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=2, gpus=0, memory=4.05%)
# 	-26.4648	 = Validation score   (-root_mean_squared_error)
# 	1177.48s	 = Training   runtime
# 	3.54s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 17223.18s of the 30427.72s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=4.45%)
# 	-26.4591	 = Validation score   (-root_mean_squared_error)
# 	92.55s	 = Training   runtime
# 	2.98s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 17125.76s of the 30330.30s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=5.77%)
# 	-26.4585	 = Validation score   (-root_mean_squared_error)
# 	139.74s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 16981.45s of the 30185.99s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=2, gpus=0, memory=4.05%)
# 	-26.4641	 = Validation score   (-root_mean_squared_error)
# 	2326.56s	 = Training   runtime
# 	4.05s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 14651.14s of the 27855.68s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=4.31%)
# 	-26.4583	 = Validation score   (-root_mean_squared_error)
# 	139.26s	 = Training   runtime
# 	8.59s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 14506.84s of the 27711.38s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=7.41%)
# 	-26.4863	 = Validation score   (-root_mean_squared_error)
# 	5736.18s	 = Training   runtime
# 	17.2s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 8764.68s of the 21969.22s of remaining time.
# 	Memory not enough to fit 10 folds in parallel. Will train 8 folds in parallel instead (Estimated 8.19% memory usage per fold, 65.53%/80.00% total).
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=8.19%)
# 	-26.4597	 = Validation score   (-root_mean_squared_error)
# 	366.77s	 = Training   runtime
# 	1.45s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 8392.31s of the 21596.85s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=4.25%)
# 	-26.4587	 = Validation score   (-root_mean_squared_error)
# 	240.92s	 = Training   runtime
# 	16.09s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 8144.82s of the 21349.36s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=2, gpus=0, memory=4.05%)
# 	-26.4705	 = Validation score   (-root_mean_squared_error)
# 	3803.54s	 = Training   runtime
# 	5.24s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 4337.36s of the 17541.90s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=6.33%)
# 	-26.4622	 = Validation score   (-root_mean_squared_error)
# 	175.92s	 = Training   runtime
# 	7.61s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 4155.97s of the 17360.51s of remaining time.
# 	-26.5021	 = Validation score   (-root_mean_squared_error)
# 	687.14s	 = Training   runtime
# 	34.37s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 3432.30s of the 16636.84s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=5.64%)
# 	-26.4595	 = Validation score   (-root_mean_squared_error)
# 	156.36s	 = Training   runtime
# 	0.42s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 3271.23s of the 16475.77s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=7.46%)
# 	-26.4697	 = Validation score   (-root_mean_squared_error)
# 	672.94s	 = Training   runtime
# 	4.72s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 2593.43s of the 15797.97s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=6.23%)
# 	-26.4591	 = Validation score   (-root_mean_squared_error)
# 	369.14s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 2219.25s of the 15423.79s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 144 due to low time. Expected time usage reduced from 4592.6s -> 2218.1s...
# 	-26.6381	 = Validation score   (-root_mean_squared_error)
# 	2261.42s	 = Training   runtime
# 	22.12s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 2638.93s of the 13137.67s of remaining time.
# 	Ensemble Weights: {'CatBoost_r177_BAG_L1': 0.36, 'XGBoost_BAG_L1': 0.2, 'LightGBM_BAG_L1': 0.12, 'LightGBMLarge_BAG_L1': 0.12, 'RandomForestMSE_BAG_L1': 0.08, 'ExtraTreesMSE_BAG_L1': 0.04, 'LightGBM_r131_BAG_L1': 0.04, 'RandomForest_r195_BAG_L1': 0.04}
# 	-26.4564	 = Validation score   (-root_mean_squared_error)
# 	1.63s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 13135.99s of the 13135.85s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=5.31%)
# 	-26.456	 = Validation score   (-root_mean_squared_error)
# 	101.49s	 = Training   runtime
# 	2.57s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 13029.08s of the 13028.94s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=5.29%)
# 	-26.4561	 = Validation score   (-root_mean_squared_error)
# 	88.17s	 = Training   runtime
# 	1.93s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 12935.76s of the 12935.61s of remaining time.
# 	-26.5101	 = Validation score   (-root_mean_squared_error)
# 	11603.14s	 = Training   runtime
# 	47.73s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 1282.70s of the 1282.56s of remaining time.
# 	Fitting 10 child models (S1F1 - S1F10) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=1, gpus=0, memory=6.88%)
# 	-26.4555	 = Validation score   (-root_mean_squared_error)
# 	142.18s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 1134.97s of the 1134.83s of remaining time.
# 	Warning: Reducing model 'n_estimators' from 300 -> 231 due to low time. Expected time usage reduced from 1467.4s -> 1133.2s...
# 	-26.5054	 = Validation score   (-root_mean_squared_error)
# 	1165.57s	 = Training   runtime
# 	33.53s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 1313.60s of the -66.47s of remaining time.
# 	Ensemble Weights: {'CatBoost_BAG_L2': 0.429, 'LightGBM_BAG_L2': 0.286, 'LightGBMXT_BAG_L2': 0.143, 'RandomForestMSE_BAG_L1': 0.048, 'XGBoost_BAG_L1': 0.048, 'RandomForestMSE_BAG_L2': 0.048}
# 	-26.4548	 = Validation score   (-root_mean_squared_error)
# 	2.45s	 = Training   runtime
# 	0.01s	 = Validation runtime
# AutoGluon training complete, total runtime = 39669.33s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 463.4 rows/s (52417 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/kaggle/working/AG_beats_models")

# %%
## -- Get Summary -- 
print(f"""
    {'█'*5}| Total models : {len(predictor.model_names())}
    {'█'*5}| Best model   : {predictor.model_best}
        """)

## -- Observe RUN 1 RESULTS --
leaderboard = predictor.leaderboard(silent=True)
display(leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral"))
# Out:
#     █████| Total models : 29
#     █████| Best model   : WeightedEnsemble_L3
# <style type="text/css">
# #T_f6dbe_row0_col1, #T_f6dbe_row1_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_f6dbe_row2_col1, #T_f6dbe_row3_col1 {
#   background-color: #5c51a3;
#   color: #f1f1f1;
# }
# #T_f6dbe_row4_col1 {
#   background-color: #5b53a4;
#   color: #f1f1f1;
# }
# #T_f6dbe_row5_col1, #T_f6dbe_row6_col1 {
#   background-color: #5758a6;
#   color: #f1f1f1;
# }
# #T_f6dbe_row7_col1, #T_f6dbe_row8_col1, #T_f6dbe_row9_col1, #T_f6dbe_row10_col1, #T_f6dbe_row11_col1 {
#   background-color: #555aa7;
#   color: #f1f1f1;
# }
# #T_f6dbe_row12_col1, #T_f6dbe_row13_col1, #T_f6dbe_row14_col1, #T_f6dbe_row15_col1 {
#   background-color: #545ca8;
#   color: #f1f1f1;
# }
# #T_f6dbe_row16_col1 {
#   background-color: #4d65ad;
#   color: #f1f1f1;
# }
# #T_f6dbe_row17_col1 {
#   background-color: #496aaf;
#   color: #f1f1f1;
# }
# #T_f6dbe_row18_col1 {
#   background-color: #486cb0;
#   color: #f1f1f1;
# }
# #T_f6dbe_row19_col1 {
#   background-color: #4175b4;
#   color: #f1f1f1;
# }
# #T_f6dbe_row20_col1 {
#   background-color: #3b7cb7;
#   color: #f1f1f1;
# }
# #T_f6dbe_row21_col1 {
#   background-color: #3a7eb8;
#   color: #f1f1f1;
# }
# #T_f6dbe_row22_col1 {
#   background-color: #56b0ad;
#   color: #f1f1f1;
# }
# #T_f6dbe_row23_col1 {
#   background-color: #66c2a5;
#   color: #000000;
# }
# #T_f6dbe_row24_col1 {
#   background-color: #8fd2a4;
#   color: #000000;
# }
# #T_f6dbe_row25_col1 {
#   background-color: #99d6a4;
#   color: #000000;
# }
# #T_f6dbe_row26_col1 {
#   background-color: #a4daa4;
#   color: #000000;
# }
# #T_f6dbe_row27_col1 {
#   background-color: #acdda4;
#   color: #000000;
# }
# #T_f6dbe_row28_col1 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f6dbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6dbe_level0_col0" class="col_heading level0 col0" >model</th>
#       <th id="T_f6dbe_level0_col1" class="col_heading level0 col1" >score_val</th>
#       <th id="T_f6dbe_level0_col2" class="col_heading level0 col2" >eval_metric</th>
#       <th id="T_f6dbe_level0_col3" class="col_heading level0 col3" >pred_time_val</th>
#       <th id="T_f6dbe_level0_col4" class="col_heading level0 col4" >fit_time</th>
#       <th id="T_f6dbe_level0_col5" class="col_heading level0 col5" >pred_time_val_marginal</th>
#       <th id="T_f6dbe_level0_col6" class="col_heading level0 col6" >fit_time_marginal</th>
#       <th id="T_f6dbe_level0_col7" class="col_heading level0 col7" >stack_level</th>
#       <th id="T_f6dbe_level0_col8" class="col_heading level0 col8" >can_infer</th>
#       <th id="T_f6dbe_level0_col9" class="col_heading level0 col9" >fit_order</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6dbe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6dbe_row0_col0" class="data row0 col0" >WeightedEnsemble_L3</td>
#       <td id="T_f6dbe_row0_col1" class="data row0 col1" >-26.454849</td>
#       <td id="T_f6dbe_row0_col2" class="data row0 col2" >root_mean_squared_error</td>
#       <td id="T_f6dbe_row0_col3" class="data row0 col3" >271.401770</td>
#       <td id="T_f6dbe_row0_col4" class="data row0 col4" >38160.465629</td>
#       <td id="T_f6dbe_row0_col5" class="data row0 col5" >0.007601</td>
#       <td id="T_f6dbe_row0_col6" class="data row0 col6" >2.446162</td>
#       <td id="T_f6dbe_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_f6dbe_row0_col8" class="data row0 col8" >True</td>
#       <td id="T_f6dbe_row0_col9" class="data row0 col9" >29</td>
#     </tr>
#     <tr>
#       <th id="T_f6dbe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f6dbe_row1_col0" class="data row1 col0" >CatBoost_BAG_L2</td>
#       <td id="T_f6dbe_row1_col1" class="data row1 col1" >-26.455516</td>
#       <td id="T_f6dbe_row1_col2" class="data row1 col2" >root_mean_squared_error</td>
#       <td id="T_f6dbe_row1_col3" class="data row1 col3" >219.159718</td>
#       <td id="T_f6dbe_row1_col4" class="data row1 col4" >26365.221028</td>
#       <td id="T_f6dbe_row1_col5" class="data row1 col5" >0.494444</td>
#       <td id="T_f6dbe_row1_col6" class="data row1 col6" >142.179285</td>
#       <td id="T_f6dbe_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_f6dbe_row1_col8" class="data row1 col8" >True</td>
#       <td id="T_f6dbe_row1_col9" class="data row1 col9" >27</td>
#     </tr>
#     <tr>
#       <th id="T_f6dbe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f6dbe_row2_col0" class="data row2 col0" >LightGBMXT_BAG_L2</td>
#       <td id="T_f6dbe_row2_col1" class="data row2 col1" >-26.456025</td>
#       <td id="T_f6dbe_row2_col2" class="data row2 col2" >root_mean_squared_error</td>
#       <td id="T_f6dbe_row2_col3" class="data row2 col3" >221.239640</td>
#       <td id="T_f6dbe_row2_col4" class="data row2 col4" >26324.533571</td>
#       <td id="T_f6dbe_row2_col5" class="data row2 col5" >2.574365</td>
#       <td id="T_f6dbe_row2_col6" class="data row2 col6" >101.491828</td>
#       <td id="T_f6dbe_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_f6dbe_row2_col8" class="data row2 col8" >True</td>
#       <td id="T_f6dbe_row2_col9" class="data row2 col9" >24</td>
#     </tr>
#     <tr>
#       <th id="T_f6dbe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f6dbe_row3_col0" class="data row3 col0" >LightGBM_BAG_L2</td>
#       <td id="T_f6dbe_row3_col1" class="data row3 col1" >-26.456142</td>
#       <td id="T_f6dbe_row3_col2" class="data row3 col2" >root_mean_squared_error</td>
#       <td id="T_f6dbe_row3_col3" class="data row3 col3" >220.599229</td>
#       <td id="T_f6dbe_row3_col4" class="data row3 col4" >26311.210046</td>
#       <td id="T_f6dbe_row3_col5" class="data row3 col5" >1.933954</td>
#       <td id="T_f6dbe_row3_col6" class="data row3 col6" >88.168303</td>
#       <td id="T_f6dbe_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_f6dbe_row3_col8" class="data row3 col8" >True</td>
#       <td id="T_f6dbe_row3_col9" class="data row3 col9" >25</td>
#     </tr>
#     <tr>
#       <th id="T_f6dbe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f6dbe_row4_col0" class="data row4 col0" >WeightedEnsemble_L2</td>
#       <td id="T_f6dbe_row4_col1" class="data row4 col1" >-26.456429</td>
#       <td id="T_f6dbe_row4_col2" class="data row4 col2" >root_mean_squared_error</td>
#       <td id="T_f6dbe_row4_col3" class="data row4 col3" >112.576538</td>
#       <td id="T_f6dbe_row4_col4" class="data row4 col4" >9135.562226</td>
#       <td id="T_f6dbe_row4_col5" class="data row4 col5" >0.006764</td>
#       <td id="T_f6dbe_row4_col6" class="data row4 col6" >1.634728</td>
#       <td id="T_f6dbe_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_f6dbe_row4_col8" class="data row4 col8" >True</td>
#       <td id="T_f6dbe_row4_col9" class="data row4 col9" >23</td>
#     </tr>
#     <tr>
#       <th id="T_f6dbe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f6dbe_row5_col0" class="data row5 col0" >LightGBM_r131_BAG_L1</td>
#       <td id="T_f6dbe_row5_col1" class="data row5 col1" >-26.458327</td>
#       <td id="T_f6dbe_row5_col2" class="data row5 col2" >root_mean_squared_error</td>
#       <td id="T_f6dbe_row5_col3" class="data row5 col3" >8.592968</td>
#       <td id="T_f6dbe_row5_col4" class="data row5 col4" >139.257181</td>
#       <td id="T_f6dbe_row5_col5" class="data row5 col5" >8.592968</td>
#       <td id="T_f6dbe_row5_col6" class="data row5 col6" >139.257181</td>
#       <td id="T_f6dbe_row5_col7" class="data row5 col7" >1</td>
#       <td id="T_f6dbe_row5_col8" class="data row5 col8" >True</td>
#       <td id="T_f6dbe_row5_col9" class="data row5 col9" >12</td>
#     </tr>
#     <tr>
#       <th id="T_f6dbe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f6dbe_row6_col0" class="data row6 col0" >LightGBM_BAG_L1</td>
#       <td id="T_f6dbe_row6_col1" class="data row6 col1" >-26.458411</td>
#       <td id="T_f6dbe_row6_col2" class="data row6 col2" >root_mean_squared_error</td>
#       <td id="T_f6dbe_row6_col3" class="data row6 col3" >2.069532</td>
#       <td id="T_f6dbe_row6_col4" class="data row6 col4" >73.961075</td>
#       <td id="T_f6dbe_row6_col5" class="data row6 col5" >2.069532<

# %%
## -- RUN 2: Use original data as extra learning input --
# predictor.fit_pseudolabel(
#                 orig,
#                 use_ensemble = True,
#                 fit_ensemble = True,
#                 time_limit   = 3600*5,
#                 ag_args_fit  = {'num_cpus': os.cpu_count() - 1},
# )

# %%
## -- Get Summary -- 
# print(f"""
#     # {'█'*5}| Total models : {len(predictor.model_names())}
#     # {'█'*5}| Best model   : {predictor.model_best}
#         """)

# # -- Observe RUN 2 RESULTS --
# leaderboard = predictor.leaderboard(silent=True)
# display(leaderboard.style.background_gradient(subset=["score_val"], cmap="Spectral"))

# %%
## -- Create folder directory to save predictions --
NAME_EXT = "_FE87_GPU"
# !mkdir /kaggle/working/AG_beats_predictions{NAME_EXT}
# PREDS_PATH = "/kaggle/working/AG_beats_predictions"

# %%
## -- Make predictions from best model --
pred_df = predictor.predict(test)
pred_df.head()
# Out:
# 0    119.024612
# 1    118.630112
# 2    119.152863
# 3    119.782425
# 4    119.815521
# Name: BeatsPerMinute, dtype: float32

# %%
## -- Generate Submission --
FILE_NAME = f"submit_AG{NAME_EXT}.csv"

submit = pd.read_csv(PATH+"sample_submission.csv")
submit[TARGET] = pred_df.values
submit.to_csv(FILE_NAME, index=False)
print(f"{'█'*5}| Submission file {FILE_NAME} saved!")
submit.head(10)
# Out:
# █████| Submission file submit_AG_FE87_GPU.csv saved!
#        id  BeatsPerMinute
# 0  524164      119.024612
# 1  524165      118.630112
# 2  524166      119.152863
# 3  524167      119.782425
# 4  524168      119.815521
# 5  524169      119.168793
# 6  524170      118.713821
# 7  524171      117.520294
# 8  524172      118.713318
# 9  524173      118.958687

# %%
## -- Generate prediction probabilities for all models --
ag_multi_test_proba = predictor.predict_multi(test)

## -- Get TEST PREDICTIONS of all models --
final_test_data = {}

for k, v in tqdm(ag_multi_test_proba.items(), desc="Exporting TEST predictions"):
    k_renamed = k.replace('_', '') + NAME_EXT
    final_test_data[k_renamed] = v

SAVE_PRED = f"/kaggle/working/AG_beats_predictions{NAME_EXT}/pred_ag{NAME_EXT}.parquet"
final_test_df = pd.DataFrame(final_test_data)
final_test_df.to_parquet(SAVE_PRED, index=False)
final_test_df.head()
# Out:
# Exporting TEST predictions:   0%|          | 0/29 [00:00<?, ?it/s]
#    LightGBMXTBAGL1_FE87_GPU  LightGBMBAGL1_FE87_GPU  \
# 0                118.952820              119.033524
# 1                118.814919              118.676025
# 2                119.041519              119.131325
# 3                119.665977              119.592896
# 4                119.217430              119.356339
#
#    RandomForestMSEBAGL1_FE87_GPU  CatBoostBAGL1_FE87_GPU  \
# 0                     118.199837              119.011208
# 1                     119.459930              118.716248
# 2                     119.564171              119.154663
# 3                     119.826302              119.827621
# 4                     122.215302              119.278465
#
#    ExtraTreesMSEBAGL1_FE87_GPU  NeuralNetFastAIBAGL1_FE87_GPU  \
# 0                   119.120041                     119.228104
# 1                   117.463905                     118.964233
# 2                   118.922432                     119.022476
# 3                   120.712044                     119.498703
# 4                   119.870377                     118.889053
#
#    XGBoostBAGL1_FE87_GPU  NeuralNetTorchBAGL1_FE87_GPU  \
# 0             119.350327                    118.984581
# 1             118.490005                    119.030006
# 2             119.058060                    118.989967
# 3             119.485046                    119.135338
# 4             119.515442                    118.361656
#
#    LightGBMLargeBAGL1_FE87_GPU  CatBoostr177BAGL1_FE87_GPU  \
# 0                   119.054771                  119.059242
# 1                   118.703430                  118.687256
# 2                   119.116501                  119.208534
# 3                   119.507668                  119.895302
# 4                   119.215103                  119.368492
#
#    NeuralNetTorchr79BAGL1_FE87_GPU  LightGBMr131BAGL1_FE87_GPU  \
# 0                       118.936989                  119.051491
# 1                       118.899635                  118.731750
# 2                       119.051315                  119.130211
# 3                       119.518311                  119.467957
# 4                       118.514687                  119.274155
#
#    NeuralNetFastAIr191BAGL1_FE87_GPU  CatBoostr9BAGL1_FE87_GPU  \
# 0                         119.593140                119.124695
# 1                         119.681778                118.548180
# 2                         119.190857                119.078468
# 3                         119.065598                119.906593
# 4                         118.495773                119.395851
#
#    LightGBMr96BAGL1_FE87_GPU  NeuralNetTorchr22BAGL1_FE87_GPU  \
# 0                 119.001907                       118.932823
# 1                 118.833511                       119.132896
# 2                 119.109863                       119.238098
# 3                 119.714394                       119.238853
# 4                 119.173790                       118.897095
#
#    XGBoostr33BAGL1_FE87_GPU  ExtraTreesr42BAGL1_FE87_GPU  \
# 0                119.290833                   118.628860
# 1                118.795471                   119.389839
# 2                119.073441                   119.295654
# 3                119.584488                   118.899490
# 4                119.367538                   119.679855
#
#    CatBoostr137BAGL1_FE87_GPU  NeuralNetFastAIr102BAGL1_FE87_GPU  \
# 0                  119.015671                         119.056007
# 1                  118.505417                         118.923195
# 2                  119.240128                         118.883240
# 3                  119.578163                         119.523788
# 4                  119.228287                         118.825363
#
#    CatBoostr13BAGL1_FE87_GPU  RandomForestr195BAGL1_FE87_GPU  \
# 0                 119.039612                      116.205948
# 1                 118.722427                      117.225853
# 2                 119.152512                      119.017357
# 3                 119.731461                      119.363937
# 4                 119.301781                      119.518311
#
#    WeightedEnsembleL2_FE87_GPU  LightGBMXTBAGL2_FE87_GPU  \
# 0                   118.933083                119.051857
# 1                   118.604607                118.687302
# 2                   119.164360                119.113670
# 3                   119.719246                119.861771
# 4                   119.628052                119.515945
#
#    LightGBMBAGL2_FE87_GPU  RandomForestMSEBAGL2_FE87_GPU  \
# 0              119.037888                     119.085121
# 1              118.777115                     117.576248
# 2              119.143005                     119.120880
# 3              119.555626                     120.898842
# 4              119.561363                     121.982239
#
#    CatBoostBAGL2_FE87_GPU  ExtraTreesMSEBAGL2_FE87_GPU  \
# 0              119.055405                   119.379845
# 1              118.553490                   117.934021
# 2              119.140884                   118.577942
# 3              119.811279                   120.472252
# 4              119.610756                   119.086098
#
#    WeightedEnsembleL3_FE87_GPU
# 0                   119.024612
# 1                   118.630112
# 2                   119.152863
# 3                   119.782425
# 4                   119.815521

# %%
## -- Get OOF predictions of all models --
ag_multi_oof_preds = {}
for model in tqdm(predictor.model_names(), desc="Processing OOF probabilities"):
    ag_multi_oof_preds[model] = predictor.predict_oof(
                                         model = model,
                                    train_data = train
                                )

final_oof_data = {}
for k, v in tqdm(ag_multi_oof_preds.items(), desc="Exporting OOF predictions"):
    k_renamed = k.replace('_', '') + NAME_EXT
    final_oof_data[k_renamed] = v
    
SAVE_OOF = f"/kaggle/working/AG_beats_predictions{NAME_EXT}/oof_ag{NAME_EXT}.parquet"
final_oof_df = pd.DataFrame(final_oof_data)
final_oof_df.to_parquet(SAVE_OOF, index=False)
final_oof_df.head()
# Out:
# Processing OOF probabilities:   0%|          | 0/29 [00:00<?, ?it/s]
# Exporting OOF predictions:   0%|          | 0/29 [00:00<?, ?it/s]
#    LightGBMXTBAGL1_FE87_GPU  LightGBMBAGL1_FE87_GPU  \
# 0                118.919388              119.012894
# 1                119.244629              118.986000
# 2                118.801880              118.926208
# 3                118.437737              118.675400
# 4                119.037102              119.752319
#
#    RandomForestMSEBAGL1_FE87_GPU  CatBoostBAGL1_FE87_GPU  \
# 0                     119.707573              118.733200
# 1                     119.136757              118.952728
# 2                     120.805069              119.208939
# 3                     120.201248              118.771431
# 4                     118.476448              119.048943
#
#    ExtraTreesMSEBAGL1_FE87_GPU  NeuralNetFastAIBAGL1_FE87_GPU  \
# 0                   118.225655                     118.812248
# 1                   118.525810                     119.330948
# 2                   118.762543                     119.153214
# 3                   117.496002                     118.358261
# 4                   118.972054                     120.056602
#
#    XGBoostBAGL1_FE87_GPU  NeuralNetTorchBAGL1_FE87_GPU  \
# 0             118.976700                    118.890381
# 1             119.105133                    119.788780
# 2             119.266716                    119.019424
# 3             119.596420                    119.877739
# 4             118.582123                    119.384102
#
#    LightGBMLargeBAGL1_FE87_GPU  CatBoostr177BAGL1_FE87_GPU  \
# 0                   118.941269                  118.900215
# 1                   118.996292                  118.992317
# 2                   118.524315                  119.165009
# 3                   118.121033                  118.900360
# 4                   119.402100                  118.680191
#
#    NeuralNetTorchr79BAGL1_FE87_GPU  LightGBMr131BAGL1_FE87_GPU  \
# 0                       118.226746                  119.038506
# 1                       120.176353                  118.966904
# 2                       119.227684                  118.758362
# 3                       118.823082                  118.478928
# 4                       118.662560                  119.847839
#
#    NeuralNetFastAIr191BAGL1_FE87_GPU  CatBoostr9BAGL1_FE87_GPU  \
# 0                         118.525665                118.751884
# 1                         120.159256                119.013527
# 2                         119.783104                119.249565
# 3                         117.113647                118.788216
# 4                         119.656235                119.080078
#
#    LightGBMr96BAGL1_FE87_GPU  NeuralNetTorchr22BAGL1_FE87_GPU  \
# 0                 118.885292                       119.143539
# 1                 119.013489                       119.971344
# 2                 118.791435                       117.654770
# 3                 118.718552                       119.892464
# 4                 119.145134                       119.110298
#
#    XGBoostr33BAGL1_FE87_GPU  ExtraTreesr42BAGL1_FE87_GPU  \
# 0                119.141037                   115.708702
# 1                119.201401                   117.866463
# 2                118.820839                   120.074524
# 3                117.708763                   114.859619
# 4                119.070076                   120.388344
#
#    CatBoostr137BAGL1_FE87_GPU  NeuralNetFastAIr102BAGL1_FE87_GPU  \
# 0                  118.969788                         118.235794
# 1                  119.048813                         120.030052
# 2                  119.292374                         118.028290
# 3                  118.850784                         119.368225
# 4                  119.201111                         117.829399
#
#    CatBoostr13BAGL1_FE87_GPU  RandomForestr195BAGL1_FE87_GPU  \
# 0                 118.925423                      124.289764
# 1                 118.760979                      118.260498
# 2                 118.871979                      115.486145
# 3                 118.841354                      119.062729
# 4                 118.948051                      120.828308
#
#    WeightedEnsembleL2_FE87_GPU  LightGBMXTBAGL2_FE87_GPU  \
# 0                   119.192680                118.839493
# 1                   118.977203                119.075058
# 2                   119.031502                119.453232
# 3                   118.956596                118.796501
# 4                   119.003868                119.521660
#
#    LightGBMBAGL2_FE87_GPU  RandomForestMSEBAGL2_FE87_GPU  \
# 0              118.998001                     117.110222
# 1              119.093742                     121.119560
# 2              118.759636                     116.516289
# 3              118.739700                     116.689758
# 4              120.258247                     117.975166
#
#    CatBoostBAGL2_FE87_GPU  ExtraTreesMSEBAGL2_FE87_GPU  \
# 0              118.945602                   118.635849
# 1              119.142754                   117.084007
# 2              119.111717                   118.953346
# 3              118.635826                   117.306938
# 4              119.075165                   116.764954
#
#    WeightedEnsembleL3_FE87_GPU
# 0                   118.895782
# 1                   119.211143
# 2                   119.024338
# 3                   118.716072
# 4                   119.372604

# %%
predictor.plot_ensemble_model(filename='ensemble_model.png')
display(Image('./AG_beats_models/ensemble_model.png'))

# %%
# !zip -r /kaggle/working/AG_beats_models /kaggle/working/AG_beats_models.zip
# !zip -r AG_beats_predictions{NAME_EXT}.zip /kaggle/working/AG_beats_predictions{NAME_EXT}
# Out:
#   adding: kaggle/working/AG_beats_predictions_FE87_GPU/ (stored 0%)
#   adding: kaggle/working/AG_beats_predictions_FE87_GPU/pred_ag_FE87_GPU.parquet (deflated 14%)
#   adding: kaggle/working/AG_beats_predictions_FE87_GPU/oof_ag_FE87_GPU.parquet (deflated 12%)

# %%
## -- EXTRACT MODEL AND SCORES --
result_dict = dict(zip(leaderboard['model'], leaderboard['score_val']))
result_df = pd.DataFrame.from_dict(result_dict, orient='index').sort_values(0)

max_score = result_df.max().item()
min_score = result_df.min().item()

## -- PLOT MODELS & SCORES --
plt.figure(figsize=(18, 10))
plt.stem(
    result_df.index,
    result_df[0],
    orientation = 'horizontal',
    bottom = min_score - 0.0055,
    markerfmt = 'C3o'
)
plt.xlim(min_score - 0.006, max_score + 0.03)
plt.xlabel('Score (RMSE)')
plt.title('-- RMSE (OOF Predictions) --', fontsize=15)

for i, value in enumerate(result_df[0]):
    plt.text(value+1e-3, i, f'{abs(value):.5f}', ha='left', va='center')

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
## -- OPTIONAL: Remove stored files --
# !rm -r /kaggle/working/AG_beats_models
# !rm -r /kaggle/working/AG_beats_predictions{NAME_EXT}

# %%
print(f"""
{'-'*48}
{'█'*5} | - AUTOGLUON NOTEBOOK COMPLETE! - | {'█'*5}
{'-'*48}
""")
# Out:
# ------------------------------------------------
# █████ | - AUTOGLUON NOTEBOOK COMPLETE! - | █████
# ------------------------------------------------
